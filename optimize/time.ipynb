# %% [markdown]
# # Predicting DWPC Query runtime ahead of time

# %%
import json

import matplotlib.pyplot
import pandas
import numpy
import seaborn
import mpld3

# %matplotlib inline

# %%
path = '../all-features/data/metapaths.json'
with open(path) as fp:
    metapaths = json.load(fp)

# %%
dwpc_df = pandas.read_table('../all-features/data/dwpc.tsv.bz2')
dwpc_df.head(2)
# Out:
# /home/dhimmels/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/dhimmels/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
#                  hetnet compound_id    disease_id metapath  PC    w  DWPC  \
# 0  rephetio-v2.0_perm-5     DB00014  DOID:0060073  CpDpCpD   0  0.4   0.0
# 1         rephetio-v2.0     DB00014    DOID:10283  CpDpCpD   0  0.4   0.0
#
#    seconds
# 0  0.04323
# 1  0.04684

# %%
# Number of queries
len(dwpc_df)
# Out:
# 46867572

# %%
time_df = dwpc_df.groupby('metapath').seconds.mean().reset_index()
len(time_df)
# Out:
# 1206

# %%
cols = ['sequential_complexity', 'optimal_join_complexity', 'midpoint_join_complexity']

rows = [[
        item['abbreviation'], 
        item['join_complexities'][item['midpoint_index']], 
        item['join_complexities'][item['optimal_join_index']],
        item['join_complexities'][-1],
        item['join_complexities'][0],
    ] for item in metapaths]
complexity_df = pandas.DataFrame(rows, columns=
    ['metapath', 'midpoint_complexity', 'optimal_complexity', 'forward_complexity', 'backward_complexity'])
complexity_df = time_df.merge(complexity_df)
complexity_df['log10_seconds_per_query'] = numpy.log10(complexity_df['seconds'])

# %%
complexity_df.head(2)
# Out:
#       metapath   seconds  midpoint_complexity  optimal_complexity  \
# 0  CbG<rG<rGaD  0.035994              3.10150            2.859092
# 1  CbG<rG<rGdD  0.022836              2.90328            2.640056
#
#    forward_complexity  backward_complexity  log10_seconds_per_query
# 0            2.859092             3.913263                -1.443772
# 1            2.640056             3.694227                -1.641372

# %% [markdown]
# ## sequential complexity

# %%
matplotlib.pyplot.figure(figsize=(10, 7))
ax = seaborn.regplot('forward_complexity', 'log10_seconds_per_query', data=complexity_df,
    lowess=True, scatter_kws={'alpha': 0.5}, line_kws={'color': 'black'}, ci=False)
points = ax.collections[0]
labels = complexity_df.metapath.tolist()
tooltip = mpld3.plugins.PointLabelTooltip(points, labels)
mpld3.plugins.connect(ax.figure, tooltip)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el29727140185190105216503695522"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el29727140185190105216503695522", {"axes": [{"axesbg": "#EAEAF2", "axes": [{"tickvalues": null, "fontsize": 10.0, "grid": {"alpha": 1.0, "dasharray": "10,0", "color": "#FFFFFF", "gridOn": true}, "nticks": 9, "tickformat": null, "position": "bottom", "scale": "linear"}, {"tickvalues": null, "fontsize": 10.0, "grid": {"alpha": 1.0, "dasharray": "10,0", "color": "#FFFFFF", "gridOn": true}, "nticks": 8, "tickformat": null, "position": "left", "scale": "linear"}], "yscale": "linear", "collections": [{"offsetcoordinates": "data", "alphas": [0.5], "yindex": 1, "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "edgecolors": ["#4C72B0"], "id": "el29727140185180172072", "pathcoordinates": "display", "offsets": "data02", "facecolors": ["#4C72B0"], "xindex": 0, "zorder": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgewidths": [0.0]}], "axesbgalpha": null, "bbox": [0.125, 0.125, 0.775, 0.775], "zoomable": true, "markers": [], "xdomain": [-2.0, 6.0], "lines": [{"dasharray": "10,0", "yindex": 1, "coordinates": "data", "id": "el29727140185191303824", "alpha": 1, "color": "#000000", "xindex": 0, "zorder": 2, "data": "data01", "linewidth": 2.625}], "xscale": "linear", "ydomain": [-2.5, 1.0], "sharex": [], "texts": [{"coordinates": "axes", "color": "#262626", "fontsize": 11.0, "text": "forward_complexity", "alpha": 1, "rotation": -0.0, "h_anchor": "middle", "id": "el29727140185181545528", "v_baseline": "hanging", "position": [0.5, -0.05376344086021506], "zorder": 3}, {"coordinates": "axes", "color": "#262626", "fontsize": 11.0, "text": "log10_seconds_per_query", "alpha": 1, "rotation": -90.0, "h_anchor": "middle", "id": "el29727140185180170616", "v_baseline": "auto", "position": [-0.05719086021505375, 0.5], "zorder": 3}], "ylim": [-2.5, 1.0], "images": [], "xlim": [-2.0, 6.0], "id": "el29727140185190107792", "sharey": [], "paths": []}], "width": 800.0, "height": 560.0, "id": "el29727140185190105216", "plugins": [{"type": "reset"}, {"button": true, "type": "zoom", "enabled": false}, {"button": true, "type": "boxzoom", "enabled": false}, {"type": "tooltip", "id": "el29727140185180172072", "labels": ["CbG<rG<rGaD", "CbG<rG<rGdD", "CbG<rG<rGuD", "CbG<rGaD", "CbG<rGaDrD", "CbG<rGbCpD", "CbG<rGbCtD", "CbG<rGcGaD", "CbG<rGcGdD", "CbG<rGcGuD", "CbG<rGdAlD", "CbG<rGdCpD", "CbG<rGdCtD", "CbG<rGdD", "CbG<rGdDrD", "CbG<rGeAlD", "CbG<rGiGaD", "CbG<rGiGdD", "CbG<rGiGuD", "CbG<rGr>GaD", "CbG<rGr>GdD", "CbG<rGr>GuD", "CbG<rGuAlD", "CbG<rGuCpD", "CbG<rGuCtD", "CbG<rGuD", "CbG<rGuDrD", "CbGaD", "CbGaDaGaD", "CbGaDaGdD", "CbGaDaGuD", "CbGaDdGaD", "CbGaDdGdD", "CbGaDdGuD", "CbGaDlAlD", "CbGaDpCpD", "CbGaDpCtD", "CbGaDpSpD", "CbGaDrD", "CbGaDrDrD", "CbGaDtCpD", "CbGaDtCtD", "CbGaDuGaD", "CbGaDuGdD", "CbGaDuGuD", "CbGbCbGaD", "CbGbCbGdD", "CbGbCbGuD", "CbGbCdGaD", "CbGbCdGdD", "CbGbCdGuD", "CbGbCpD", "CbGbCpDrD", "CbGbCrCpD", "CbGbCrCtD", "CbGbCtD", "CbGbCtDrD", "CbGbCuGaD", "CbGbCuGdD", "CbGbCuGuD", "CbGcG<rGaD", "CbGcG<rGdD", "CbGcG<rGuD", "CbGcGaD", "CbGcGaDrD", "CbGcGbCpD", "CbGcGbCtD", "CbGcGcGaD", "CbGcGcGdD", "CbGcGcGuD", "CbGcGdAlD", "CbGcGdCpD", "CbGcGdCtD", "CbGcGdD", "CbGcGdDrD", "CbGcGeAlD", "CbGcGiGaD", "CbGcGiGdD", "CbGcGiGuD" ...

# %% [markdown]
# ## optimal join complexity

# %%
matplotlib.pyplot.figure(figsize=(10, 7))
ax = seaborn.regplot('optimal_complexity', 'log10_seconds_per_query', data=complexity_df,
    lowess=True, scatter_kws={'alpha': 0.5}, line_kws={'color': 'black'}, ci=False)
points = ax.collections[0]
labels = complexity_df.metapath.tolist()
tooltip = mpld3.plugins.PointLabelTooltip(points, labels)
mpld3.plugins.connect(ax.figure, tooltip)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el297271401851800836483208696649"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el297271401851800836483208696649", {"axes": [{"axesbg": "#EAEAF2", "axes": [{"tickvalues": null, "fontsize": 10.0, "grid": {"alpha": 1.0, "dasharray": "10,0", "color": "#FFFFFF", "gridOn": true}, "nticks": 6, "tickformat": null, "position": "bottom", "scale": "linear"}, {"tickvalues": null, "fontsize": 10.0, "grid": {"alpha": 1.0, "dasharray": "10,0", "color": "#FFFFFF", "gridOn": true}, "nticks": 8, "tickformat": null, "position": "left", "scale": "linear"}], "yscale": "linear", "collections": [{"offsetcoordinates": "data", "alphas": [0.5], "yindex": 1, "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "edgecolors": ["#4C72B0"], "id": "el29727140185217941856", "pathcoordinates": "display", "offsets": "data02", "facecolors": ["#4C72B0"], "xindex": 0, "zorder": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgewidths": [0.0]}], "axesbgalpha": null, "bbox": [0.125, 0.125, 0.775, 0.775], "zoomable": true, "markers": [], "xdomain": [-1.0, 4.0], "lines": [{"dasharray": "10,0", "yindex": 1, "coordinates": "data", "id": "el29727140185180169328", "alpha": 1, "color": "#000000", "xindex": 0, "zorder": 2, "data": "data01", "linewidth": 2.625}], "xscale": "linear", "ydomain": [-2.5, 1.0], "sharex": [], "texts": [{"coordinates": "axes", "color": "#262626", "fontsize": 11.0, "text": "optimal_complexity", "alpha": 1, "rotation": -0.0, "h_anchor": "middle", "id": "el29727140185217856288", "v_baseline": "hanging", "position": [0.5, -0.05376344086021506], "zorder": 3}, {"coordinates": "axes", "color": "#262626", "fontsize": 11.0, "text": "log10_seconds_per_query", "alpha": 1, "rotation": -90.0, "h_anchor": "middle", "id": "el29727140185217919800", "v_baseline": "auto", "position": [-0.05719086021505375, 0.5], "zorder": 3}], "ylim": [-2.5, 1.0], "images": [], "xlim": [-1.0, 4.0], "id": "el29727140185180168936", "sharey": [], "paths": []}], "width": 800.0, "height": 560.0, "id": "el29727140185180083648", "plugins": [{"type": "reset"}, {"button": true, "type": "zoom", "enabled": false}, {"button": true, "type": "boxzoom", "enabled": false}, {"type": "tooltip", "id": "el29727140185217941856", "labels": ["CbG<rG<rGaD", "CbG<rG<rGdD", "CbG<rG<rGuD", "CbG<rGaD", "CbG<rGaDrD", "CbG<rGbCpD", "CbG<rGbCtD", "CbG<rGcGaD", "CbG<rGcGdD", "CbG<rGcGuD", "CbG<rGdAlD", "CbG<rGdCpD", "CbG<rGdCtD", "CbG<rGdD", "CbG<rGdDrD", "CbG<rGeAlD", "CbG<rGiGaD", "CbG<rGiGdD", "CbG<rGiGuD", "CbG<rGr>GaD", "CbG<rGr>GdD", "CbG<rGr>GuD", "CbG<rGuAlD", "CbG<rGuCpD", "CbG<rGuCtD", "CbG<rGuD", "CbG<rGuDrD", "CbGaD", "CbGaDaGaD", "CbGaDaGdD", "CbGaDaGuD", "CbGaDdGaD", "CbGaDdGdD", "CbGaDdGuD", "CbGaDlAlD", "CbGaDpCpD", "CbGaDpCtD", "CbGaDpSpD", "CbGaDrD", "CbGaDrDrD", "CbGaDtCpD", "CbGaDtCtD", "CbGaDuGaD", "CbGaDuGdD", "CbGaDuGuD", "CbGbCbGaD", "CbGbCbGdD", "CbGbCbGuD", "CbGbCdGaD", "CbGbCdGdD", "CbGbCdGuD", "CbGbCpD", "CbGbCpDrD", "CbGbCrCpD", "CbGbCrCtD", "CbGbCtD", "CbGbCtDrD", "CbGbCuGaD", "CbGbCuGdD", "CbGbCuGuD", "CbGcG<rGaD", "CbGcG<rGdD", "CbGcG<rGuD", "CbGcGaD", "CbGcGaDrD", "CbGcGbCpD", "CbGcGbCtD", "CbGcGcGaD", "CbGcGcGdD", "CbGcGcGuD", "CbGcGdAlD", "CbGcGdCpD", "CbGcGdCtD", "CbGcGdD", "CbGcGdDrD", "CbGcGeAlD", "CbGcGiGaD", "CbGcGiGdD", "CbGcGiGuD ...

# %% [markdown]
# ## midpoint_join_complexity

# %%
matplotlib.pyplot.figure(figsize=(10, 7))
ax = seaborn.regplot('midpoint_complexity', 'log10_seconds_per_query', data=complexity_df,
    lowess=True, scatter_kws={'alpha': 0.5}, line_kws={'color': 'black'}, ci=False)
points = ax.collections[0]
labels = complexity_df.metapath.tolist()
tooltip = mpld3.plugins.PointLabelTooltip(points, labels)
mpld3.plugins.connect(ax.figure, tooltip)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el297271401852177444566663029926"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el297271401852177444566663029926", {"axes": [{"axesbg": "#EAEAF2", "axes": [{"tickvalues": null, "fontsize": 10.0, "grid": {"alpha": 1.0, "dasharray": "10,0", "color": "#FFFFFF", "gridOn": true}, "nticks": 7, "tickformat": null, "position": "bottom", "scale": "linear"}, {"tickvalues": null, "fontsize": 10.0, "grid": {"alpha": 1.0, "dasharray": "10,0", "color": "#FFFFFF", "gridOn": true}, "nticks": 8, "tickformat": null, "position": "left", "scale": "linear"}], "yscale": "linear", "collections": [{"offsetcoordinates": "data", "alphas": [0.5], "yindex": 1, "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "edgecolors": ["#4C72B0"], "id": "el29727140185217065928", "pathcoordinates": "display", "offsets": "data02", "facecolors": ["#4C72B0"], "xindex": 0, "zorder": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgewidths": [0.0]}], "axesbgalpha": null, "bbox": [0.125, 0.125, 0.775, 0.775], "zoomable": true, "markers": [], "xdomain": [-1.0, 5.0], "lines": [{"dasharray": "10,0", "yindex": 1, "coordinates": "data", "id": "el29727140185217091456", "alpha": 1, "color": "#000000", "xindex": 0, "zorder": 2, "data": "data01", "linewidth": 2.625}], "xscale": "linear", "ydomain": [-2.5, 1.0], "sharex": [], "texts": [{"coordinates": "axes", "color": "#262626", "fontsize": 11.0, "text": "midpoint_complexity", "alpha": 1, "rotation": -0.0, "h_anchor": "middle", "id": "el29727140185217297320", "v_baseline": "hanging", "position": [0.5, -0.05376344086021506], "zorder": 3}, {"coordinates": "axes", "color": "#262626", "fontsize": 11.0, "text": "log10_seconds_per_query", "alpha": 1, "rotation": -90.0, "h_anchor": "middle", "id": "el29727140185217352760", "v_baseline": "auto", "position": [-0.05719086021505375, 0.5], "zorder": 3}], "ylim": [-2.5, 1.0], "images": [], "xlim": [-1.0, 5.0], "id": "el29727140185180083312", "sharey": [], "paths": []}], "width": 800.0, "height": 560.0, "id": "el29727140185217744456", "plugins": [{"type": "reset"}, {"button": true, "type": "zoom", "enabled": false}, {"button": true, "type": "boxzoom", "enabled": false}, {"type": "tooltip", "id": "el29727140185217065928", "labels": ["CbG<rG<rGaD", "CbG<rG<rGdD", "CbG<rG<rGuD", "CbG<rGaD", "CbG<rGaDrD", "CbG<rGbCpD", "CbG<rGbCtD", "CbG<rGcGaD", "CbG<rGcGdD", "CbG<rGcGuD", "CbG<rGdAlD", "CbG<rGdCpD", "CbG<rGdCtD", "CbG<rGdD", "CbG<rGdDrD", "CbG<rGeAlD", "CbG<rGiGaD", "CbG<rGiGdD", "CbG<rGiGuD", "CbG<rGr>GaD", "CbG<rGr>GdD", "CbG<rGr>GuD", "CbG<rGuAlD", "CbG<rGuCpD", "CbG<rGuCtD", "CbG<rGuD", "CbG<rGuDrD", "CbGaD", "CbGaDaGaD", "CbGaDaGdD", "CbGaDaGuD", "CbGaDdGaD", "CbGaDdGdD", "CbGaDdGuD", "CbGaDlAlD", "CbGaDpCpD", "CbGaDpCtD", "CbGaDpSpD", "CbGaDrD", "CbGaDrDrD", "CbGaDtCpD", "CbGaDtCtD", "CbGaDuGaD", "CbGaDuGdD", "CbGaDuGuD", "CbGbCbGaD", "CbGbCbGdD", "CbGbCbGuD", "CbGbCdGaD", "CbGbCdGdD", "CbGbCdGuD", "CbGbCpD", "CbGbCpDrD", "CbGbCrCpD", "CbGbCrCtD", "CbGbCtD", "CbGbCtDrD", "CbGbCuGaD", "CbGbCuGdD", "CbGbCuGuD", "CbGcG<rGaD", "CbGcG<rGdD", "CbGcG<rGuD", "CbGcGaD", "CbGcGaDrD", "CbGcGbCpD", "CbGcGbCtD", "CbGcGcGaD", "CbGcGcGdD", "CbGcGcGuD", "CbGcGdAlD", "CbGcGdCpD", "CbGcGdCtD", "CbGcGdD", "CbGcGdDrD", "CbGcGeAlD", "CbGcGiGaD", "CbGcGiGdD", "CbGcGiGu ...
