# %% [markdown]
# # Investigate DWPC and degree transformation
#
# See the corresponding [Thinklab discussion](http://thinklab.com/d/193).

# %%
library(magrittr)

options(stringsAsFactors=F)

# %%
feature_df = readr::read_tsv('data/matrix/rephetio-v2.0/features.tsv.bz2')
summary_df = readr::read_tsv('data/feature-performance/primary-aurocs.tsv') %>%
  dplyr::filter(feature %in% colnames(feature_df))
degrees = dplyr::filter(summary_df, feature_type == 'degree')$feature
metapaths = dplyr::filter(summary_df, feature_type == 'dwpc')$feature

# %%
head(summary_df, 2)
head(feature_df, 2)
# Out:
# Source: local data frame [2 x 8]
#
#   feature_type feature nonzero   auroc auroc_permuted delta_auroc pval_auroc
#          (chr)   (chr)   (dbl)   (dbl)          (dbl)       (dbl)      (dbl)
# 1       degree     CbG 0.98808 0.54778        0.54904  -0.0012571   0.540220
# 2       degree    CcSE 0.95470 0.56452        0.56834  -0.0038218   0.044426
# Variables not shown: fdr_pval_auroc (dbl)
# Source: local data frame [2 x 1,218]
#
#   compound_id   disease_id status       disease_name  compound_name prior_prob
#         (chr)        (chr)  (int)              (chr)          (chr)      (dbl)
# 1     DB00014 DOID:0050741      0 alcohol dependence      Goserelin  0.0098008
# 2     DB00153 DOID:0050741      0 alcohol dependence Ergocalciferol  0.0098008
# Variables not shown: CbG (int), CcSE (int), CdG (int), CiPC (int), CpD (int),
#   CrC (int), CtD (int), CuG (int), DaG (int), DdG (int), DlA (int), DpC (int),
#   DpS (int), DrD (int), DtC (int), DuG (int), CbG<rG<rGaD (dbl), CbG<rG<rGdD
#   (dbl), CbG<rG<rGuD (dbl), CbG<rGaD (dbl), CbG<rGaDrD (dbl), CbG<rGbCpD (dbl),
#   CbG<rGbCtD (dbl), CbG<rGcGaD (dbl), CbG<rGcGdD (dbl), CbG<rGcGuD (dbl),
#   CbG<rGdAlD (dbl), CbG<rGdCpD (dbl), CbG<rGdCtD (dbl), CbG<rGdD (dbl),
#   CbG<rGdDrD (dbl), CbG<rGeAlD (dbl), CbG<rGiGaD (dbl), CbG<rGiGdD (dbl),
#   CbG<rGiGuD (dbl), CbG<rGr>GaD (dbl), CbG<rGr>GdD (dbl), CbG<rGr>GuD (dbl),
#   CbG<rGuAlD (dbl), CbG<rGuCpD (dbl), CbG<rGuCtD (dbl), CbG<rGuD (dbl),
#   CbG<rGuDrD (dbl), CbGaD (dbl), CbGaDaGaD (dbl), CbGaDaGdD (dbl), CbGaDaGuD
#   (dbl), CbGaDdGaD (dbl), CbGaDdGdD (dbl), CbGaDdGuD (dbl), CbGaDlAlD (dbl),
#   CbGaDpCpD (dbl), CbGaDpCtD (dbl), CbGaDpSpD (dbl), CbGaDrD (dbl), CbGaDrDrD
#   (dbl), CbGaDtCpD (dbl), CbGaDtCtD (dbl), CbGaDuGaD (dbl), CbGaDuGdD (dbl),
#   CbGaDuGuD (dbl), CbGbCbGaD (dbl), CbGbCbGdD (dbl), CbGbCbGuD (dbl), CbGbCdGaD
#   (dbl), CbGbCdGdD (dbl), CbGbCdGuD (dbl), CbGbCpD (dbl), CbGbCpDrD (dbl),
#   CcSEcCtDrD (dbl), CcSEcCuGaD (dbl), CcSEcCuGdD (dbl), CcSEcCuGuD (dbl),
#   CdG<rG<rGaD (dbl), CdG<rG<rGdD (dbl), CdG<rG<rGuD (dbl), CdG<rGaD (dbl),
#   CdG<rGaDrD (dbl), CdG<rGbCpD (dbl), CdG<rGbCtD (dbl), CdG<rGcGaD (dbl),
#   CdG<rGcGdD (dbl), CdG<rGcGuD (dbl), CdG<rGdAlD (dbl), CdG<rGdCpD (dbl),
#   CdG<rGdCtD (dbl), CdG<rGdD (dbl), CdG<rGdDrD (dbl), CdG<rGiGaD (dbl),
#   CdG<rGiGdD (dbl), CdG<rGiGuD (dbl), CdG<rGr>GaD (dbl), CdG<rGr>GdD (dbl),
#   CdG<rGr>GuD (dbl), CdG<rGuAlD (dbl), CdG<rGuCpD (dbl), CdG<rGuCtD (dbl),
#   CdG<rGuD (dbl), CdG<rGuDrD (dbl), CdGaD (dbl), CdGaDaGaD (dbl), CdGaDaGdD
#   (dbl), CdGaDaGuD (dbl), CdGaDdGaD (dbl), CdGaDdGdD (dbl), CdGaDdGuD (dbl),
#   CdGaDlAlD (dbl), CdGaDpCpD (dbl), CdGaDpCtD (dbl), CdGaDpSpD (dbl), CdGaDrD
#   (dbl), CdGaDrDrD (dbl), CdGaDtCpD (dbl), CdGaDtCtD (dbl), CdGaDuGaD (dbl),
#   CdGaDuGdD (dbl), CdGaDuGuD (dbl), CdGbCbGaD (dbl), CdGbCbGdD (dbl), CdGbCbGuD
#   (dbl), CdGbCdGaD (dbl), CdGbCdGdD (dbl), CdGbCdGuD (dbl), CdGbCpD (dbl),
#   CdGbCpDrD (dbl), CdGbCrCpD (dbl), CdGbCrCtD (dbl), CdGbCtD (dbl), CdGbCtDrD
#   (dbl), CdGbCuGaD (dbl), CdGbCuGdD (dbl), CdGbCuGuD (dbl), CdGcG<rGaD (dbl),
#   CdGcG<rGdD (dbl), CdGcG<rGuD (dbl), CdGcGaD (dbl), CdGcGaDrD (dbl), CdGcGbCpD
#   (dbl), CdGcGbCtD (dbl), CdGcGcGaD (dbl), CdGcGcGdD (dbl), CdGcGcGuD (dbl),
#   CdGcGdAlD (dbl), CdGcGdCpD (dbl), CdGcGdCtD (dbl), CdGcGdD (dbl), CdGcGdDrD
#   (dbl), CdGcGeAlD (dbl), CdGcGiGaD (dbl), CdGcGiGdD (dbl), CdGcGiGuD (dbl),
#   CdGcGr>GaD (dbl), CdGcGr>GdD (dbl), CdGcGr>GuD (dbl), CdGcGuAlD (dbl),
#   CdGcGuCpD (dbl), CdGcGuCtD (dbl), CdGcGuD (dbl), CdGcGuDrD (dbl), CdGdAdGaD
#   (dbl), CdGdAdGdD (dbl), CdGdAdGuD (dbl), CdGdAeGaD (dbl), CdGdAeGdD (dbl),
#   CdGdAeGuD (dbl), CdGdAlD (dbl), CdGdAlDrD (dbl), CdGdAuGaD (dbl), CdGdAuGdD
#   (dbl), CdGdAuGuD (dbl), CdGdCbGaD (dbl), CdGdCbGdD (dbl), CdGdCbGuD (dbl),
#   CdGdCdGaD (dbl), CdGdCdGdD (dbl), CdGdCdGuD (dbl), CdGdCpD (dbl), CdGdCpDrD
#   (dbl), CdGdCrCpD (dbl), CdGdCrCtD (dbl), CdGdCtD (dbl), CdGdCtDrD (dbl),
#   CdGdCuGaD (dbl), CdGdCuGdD (dbl), CdGdCuGuD (dbl), CdGdD (dbl), CdGdDaGaD
#   (dbl), CdGdDaGdD (dbl), CdGdDaGuD (dbl), CdGdDdGaD (dbl), CdGdDdGdD (dbl),
#   CdGdDdGuD (dbl), CdGdDlAlD (dbl), CdGdDpCpD (dbl), CdGdDpCtD (dbl), CdGdDpSpD
#   (dbl), CdGdDrD (dbl), CdGdDrDrD (dbl), CdGdDtCpD (dbl), CdGdDtCtD (dbl),
#   CdGdDuGaD (dbl), CdGdDuGdD (dbl), CdGdDuGuD (dbl), CdGeAdGaD (dbl), CdGeAdGdD
#   (dbl), CdGeAdGuD (dbl), CdGeAlD (dbl), CdGeAlDrD (dbl), CdGeAuGaD (dbl),
#   CdGeAuGdD (dbl), CdGeAuGuD (dbl), CdGiG<rGaD (dbl), CdGiG<rGdD (dbl),
#   CdGiG<rGuD (dbl), CdGiGaD (dbl), CdGiGaDrD (dbl), CdGiGbCpD (dbl), CdGiGbCtD
#   (dbl), CdGiGcGaD (dbl), CdGiGcGdD (dbl), CdGiGcGuD (dbl), CdGiGdAlD (dbl),
#   CdGiGdCpD (dbl), CdGiGdCtD (dbl), CdGiGdD (dbl), CdGiGdDrD (dbl), CdGiGeAlD
#   (dbl), CdGiGiGaD (dbl), CdGiGiGdD (dbl), CdGiGiGuD (dbl), CdGiGr>GaD (dbl),
#   CdGiGr>GdD (dbl), CdGiGr>GuD (dbl), CdGiGuAlD (dbl), CdGiGuCpD (dbl),
#   CdGiGuCtD (dbl), CdGiGuD (dbl), CdGiGuDrD (dbl), CdGpBPpGaD (dbl), CdGpBPpGdD
#   (dbl), CdGpBPpGuD (dbl), CdGpCCpGaD (dbl), CdGpCCpGdD (dbl), CdGpCCpGuD
#   (dbl), CdGpMFpGaD (dbl), CdGpMFpGdD (dbl), CdGpMFpGuD (dbl), CdGpPWpGaD
#   (dbl), CdGpPWpGdD (dbl), CdGpPWpGuD (dbl), CdGr>G<rGaD (dbl), CdGr>G<rGdD
#   (dbl), CdGr>G<rGuD (dbl), CdGr>GaD (dbl), CdGr>GaDrD (dbl), CdGr>GbCpD (dbl),
#   CdGr>GbCtD (dbl), CdGr>GcGaD (dbl), CdGr>GcGdD (dbl), CdGr>GcGuD (dbl),
#   CdGr>GdAlD (dbl), CdGr>GdCpD (dbl), CdGr>GdCtD (dbl), CdGr>GdD (dbl),
#   CdGr>GdDrD (dbl), CdGr>GeAlD (dbl), CdGr>GiGaD (dbl), CdGr>GiGdD (dbl),
#   CdGr>GiGuD (dbl), CdGr>Gr>GaD (dbl), CdGr>Gr>GdD (dbl), CdGr>Gr>GuD (dbl),
#   CdGr>GuAlD (dbl), CdGr>GuCpD (dbl), CdGr>GuCtD (dbl), CdGr>GuD (dbl),
#   CdGr>GuDrD (dbl), CdGuAdGaD (dbl), CdGuAdGdD (dbl), CdGuAdGuD (dbl),
#   CdGuAeGaD (dbl), CdGuAeGdD (dbl), CdGuAeGuD (dbl), CdGuAlD (dbl), CdGuAlDrD
#   (dbl), CdGuAuGaD (dbl), CdGuAuGdD (dbl), CdGuAuGuD (dbl), CdGuCbGaD (dbl),
#   CdGuCbGdD (dbl), CdGuCbGuD (dbl), CdGuCdGaD (dbl), CdGuCdGdD (dbl), CdGuCdGuD
#   (dbl), CdGuCpD (dbl), CdGuCpDrD (dbl), CdGuCrCpD (dbl), CdGuCrCtD (dbl),
#   CdGuCtD (dbl), CdGuCtDrD (dbl), CdGuCuGaD (dbl), CdGuCuGdD (dbl), CdGuCuGuD
#   (dbl), CdGuD (dbl), CdGuDaGaD (dbl), CdGuDaGdD (dbl), CdGuDaGuD (dbl),
#   CdGuDdGaD (dbl), CdGuDdGdD (dbl), CdGuDdGuD (dbl), CdGuDlAlD (dbl), CdGuDpCpD
#   (dbl), CdGuDpCtD (dbl), CdGuDpSpD (dbl), CdGuDrD (dbl), CdGuDrDrD (dbl),
#   CdGuDtCpD (dbl), CdGuDtCtD (dbl), CdGuDuGaD (dbl), CdGuDuGdD (dbl), CdGuDuGuD
#   (dbl), CiPCiCbGaD (dbl), CiPCiCbGdD (dbl), CiPCiCbGuD (dbl), CiPCiCdGaD
#   (dbl), CiPCiCdGdD (dbl), CiPCiCdGuD (dbl), CiPCiCpD (dbl), CiPCiCpDrD (dbl),
#   CiPCiCrCpD (dbl), CiPCiCrCtD (dbl), CiPCiCtD (dbl), CiPCiCtDrD (dbl),
#   CiPCiCuGaD (dbl), CiPCiCuGdD (dbl), CiPCiCuGuD (dbl), CpDaG<rGaD (dbl),
#   CpDaG<rGdD (dbl), CpDaG<rGuD (dbl), CpDaGaD (dbl), CpDaGaDrD (dbl), CpDaGbCpD
#   (dbl), CpDaGbCtD (dbl), CpDaGcGaD (dbl), CpDaGcGdD (dbl), CpDaGcGuD (dbl),
#   CpDaGdAlD (dbl), CpDaGdCpD (dbl), CpDaGdCtD (dbl), CpDaGdD (dbl), CpDaGdDrD
#   (dbl), CpDaGeAlD (dbl), CpDaGiGaD (dbl), CpDaGiGdD (dbl), CpDaGiGuD (dbl),
#   CpDaGr>GaD (dbl), CpDaGr>GdD (dbl), CpDaGr>GuD (dbl), CpDaGuAlD (dbl),
#   CpDaGuCpD (dbl), CpDaGuCtD (dbl), CpDaGuD (dbl), CpDaGuDrD (dbl), CpDdG<rGaD
#   (dbl), CpDdG<rGdD (dbl), CpDdG<rGuD (dbl), CpDdGaD (dbl), CpDdGaDrD (dbl),
#   CpDdGbCpD (dbl), CpDdGbCtD (dbl), CpDdGcGaD (dbl), CpDdGcGdD (dbl), CpDdGcGuD
#   (dbl), CpDdGdAlD (dbl), CpDdGdCpD (dbl), CpDdGdCtD (dbl), CpDdGdD (dbl),
#   CpDdGdDrD (dbl), CpDdGeAlD (dbl), CpDdGiGaD (dbl), CpDdGiGdD (dbl), CpDdGiGuD
#   (dbl), CrCbGdCpD (dbl), CrCbGdCtD (dbl), CrCbGdD (dbl), CrCbGdDrD (dbl),
#   CrCbGeAlD (dbl), CrCbGiGaD (dbl), CrCbGiGdD (dbl), CrCbGiGuD (dbl),
#   CrCbGr>GaD (dbl), CrCbGr>GdD (dbl), CrCbGr>GuD (dbl), CrCbGuAlD (dbl),
#   CrCbGuCpD (dbl), CrCbGuCtD (dbl), CrCbGuD (dbl), CrCbGuDrD (dbl), CrCcSEcCpD
#   (dbl), CrCcSEcCtD (dbl), CrCdG<rGaD (dbl), CrCdG<rGdD (dbl), CrCdG<rGuD
#   (dbl), CrCdGaD (dbl), CrCdGaDrD (dbl), CrCdGbCpD (dbl), CrCdGbCtD (dbl),
#   CrCdGcGaD (dbl), CrCdGcGdD (dbl), CrCdGcGuD (dbl), CrCdGdAlD (dbl), CrCdGdCpD
#   (dbl), CrCdGdCtD (dbl), CrCdGdD (dbl), CrCdGdDrD (dbl), CrCdGeAlD (dbl),
#   CrCdGiGaD (dbl), CrCdGiGdD (dbl), CrCdGiGuD (dbl), CrCdGr>GaD (dbl),
#   CrCdGr>GdD (dbl), CrCdGr>GuD (dbl), CrCdGuAlD (dbl), CrCdGuCpD (dbl),
#   CrCdGuCtD (dbl), CrCdGuD (dbl), CrCdGuDrD (dbl), CrCiPCiCpD (dbl), CrCiPCiCtD
#   (dbl), CrCpD (dbl), CrCpDaGaD (dbl), CrCpDaGdD (dbl), CrCpDaGuD (dbl),
#   CrCpDdGaD (dbl), CrCpDdGdD (dbl), CrCpDdGuD (dbl), CrCpDlAlD (dbl), CrCpDpCpD
#   (dbl), CrCpDpCtD (dbl), CrCpDpSpD (dbl), CrCpDrD (dbl), CrCpDrDrD (dbl),
#   CrCpDtCpD (dbl), CrCpDtCtD (dbl), CrCpDuGaD (dbl), CrCpDuGdD (dbl), CrCpDuGuD
#   (dbl), CrCrCbGaD (dbl), CrCrCbGdD (dbl), CrCrCbGuD (dbl), CrCrCdGaD (dbl),
#   CrCrCdGdD (dbl), CrCrCdGuD (dbl), CrCrCpD (dbl), CrCrCpDrD (dbl), CrCrCrCpD
#   (dbl), CrCrCrCtD (dbl), CrCrCtD (dbl), CrCrCtDrD (dbl), CrCrCuGaD (dbl),
#   CrCrCuGdD (dbl), CrCrCuGuD (dbl), CrCtD (dbl), CrCtDaGaD (dbl), CrCtDaGdD
#   (dbl), CrCtDaGuD (dbl), CrCtDdGaD (dbl), CrCtDdGdD (dbl), CrCtDdGuD (dbl),
#   CrCtDlAlD (dbl), CrCtDpCpD (dbl), CrCtDpCtD (dbl), CrCtDpSpD (dbl), CrCtDrD
#   (dbl), CrCtDrDrD (dbl), CrCtDtCpD (dbl), CrCtDtCtD (dbl), CrCtDuGaD (dbl),
#   CrCtDuGdD (dbl), CrCtDuGuD (dbl), CrCuG<rGaD (dbl), CrCuG<rGdD (dbl),
#   CrCuG<rGuD (dbl), CrCuGaD (dbl), CrCuGaDrD (dbl), CrCuGbCpD (dbl), CrCuGbCtD
#   (dbl), CrCuGcGaD (dbl), CrCuGcGdD (dbl), CrCuGcGuD (dbl), CrCuGdAlD (dbl),
#   CrCuGdCpD (dbl), CrCuGdCtD (dbl), CrCuGdD (dbl), CrCuGdDrD (dbl), CrCuGeAlD
#   (dbl), CrCuGiGaD (dbl), CrCuGiGdD (dbl), CrCuGiGuD (dbl), CrCuGr>GaD (dbl),
#   CrCuGr>GdD (dbl), CrCuGr>GuD (dbl), CrCuGuAlD (dbl), CrCuGuCpD (dbl),
#   CrCuGuCtD (dbl), CrCuGuD (dbl), CrCuGuDrD (dbl), CtDaG<rGaD (dbl), CtDaG<rGdD
#   (dbl), CtDaG<rGuD (dbl), CtDaGaD (dbl), CtDaGaDrD (dbl), CtDaGbCpD (dbl),
#   CtDaGbCtD (dbl), CtDaGcGaD (dbl), CtDaGcGdD (dbl), CtDaGcGuD (dbl), CtDaGdAlD
#   (dbl), CtDaGdCpD (dbl), CtDaGdCtD (dbl), CtDaGdD (dbl), CtDaGdDrD (dbl),
#   CtDaGeAlD (dbl), CtDaGiGaD (dbl), CtDaGiGdD (dbl), CtDaGiGuD (dbl),
#   CtDaGr>GaD (dbl), CtDaGr>GdD (dbl), CtDaGr>GuD (dbl), CtDaGuAlD (dbl),
#   CtDaGuCpD (dbl), CtDaGuCtD (dbl), CtDaGuD (dbl), CtDaGuDrD (dbl), CtDdG<rGaD
#   (dbl), CtDdG<rGdD (dbl), CtDdG<rGuD (dbl), CtDdGaD (dbl), CtDdGaDrD (dbl),
#   CtDdGbCpD (dbl), CtDdGbCtD (dbl), CtDdGcGaD (dbl), CtDdGcGdD (dbl), CtDdGcGuD
#   (dbl), CtDdGdAlD (dbl), CtDdGdCpD (dbl), CtDdGdCtD (dbl), CtDdGdD (dbl),
#   CtDdGdDrD (dbl), CtDdGeAlD (dbl), CtDdGiGaD (dbl), CtDdGiGdD (dbl), CtDdGiGuD
#   (dbl), CtDdGr>GaD (dbl), CtDdGr>GdD (dbl), CtDdGr>GuD (dbl), CtDdGuAlD (dbl),
#   CtDdGuCpD (dbl), CtDdGuCtD (dbl), CtDdGuD (dbl), CtDdGuDrD (dbl), CtDlAdGaD
#   (dbl), CtDlAdGdD (dbl), CtDlAdGuD (dbl), CtDlAeGaD (dbl), CtDlAeGdD (dbl),
#   CtDlAeGuD (dbl), CtDlAlD (dbl), CtDlAlDrD (dbl), CtDlAuGaD (dbl), CtDlAuGdD
#   (dbl), CtDlAuGuD (dbl), CtDpCbGaD (dbl), CtDpCbGdD (dbl), CtDpCbGuD (dbl),
#   CtDpCdGaD (dbl), CtDpCdGdD (dbl), CtDpCdGuD (dbl), CtDpCpD (dbl), CtDpCpDrD
#   (dbl), CtDpCrCpD (dbl), CtDpCrCtD (dbl), CtDpCtD (dbl), CtDpCtDrD (dbl),
#   CtDpCuGaD (dbl), CtDpCuGdD (dbl), CtDpCuGuD (dbl), CtDpSpD (dbl), CtDpSpDrD
#   (dbl), CtDrD (dbl), CtDrDaGaD (dbl), CtDrDaGdD (dbl), CtDrDaGuD (dbl),
#   (dbl), CuGiGiGuD (dbl), CuGiGr>GaD (dbl), CuGiGr>GdD (dbl), CuGiGr>GuD (dbl),
#   CuGiGuAlD (dbl), CuGiGuCpD (dbl), CuGiGuCtD (dbl), CuGiGuD (dbl), CuGiGuDrD
#   (dbl), CuGpBPpGaD (dbl), CuGpBPpGdD (dbl), CuGpBPpGuD (dbl), CuGpCCpGaD
#   (dbl), CuGpCCpGdD (dbl), CuGpCCpGuD (dbl), CuGpMFpGaD (dbl), CuGpMFpGdD
#   (dbl), CuGpMFpGuD (dbl), CuGpPWpGaD (dbl), CuGpPWpGdD (dbl), CuGpPWpGuD
#   (dbl), CuGr>G<rGaD (dbl), CuGr>G<rGdD (dbl), CuGr>G<rGuD (dbl), CuGr>GaD
#   (dbl), CuGr>GaDrD (dbl), CuGr>GbCpD (dbl), CuGr>GbCtD (dbl), CuGr>GcGaD
#   (dbl), CuGr>GcGdD (dbl), CuGr>GcGuD (dbl), CuGr>GdAlD (dbl), CuGr>GdCpD
#   (dbl), CuGr>GdCtD (dbl), CuGr>GdD (dbl), CuGr>GdDrD (dbl), CuGr>GeAlD (dbl),
#   CuGr>GiGaD (dbl), CuGr>GiGdD (dbl), CuGr>GiGuD (dbl), CuGr>Gr>GaD (dbl),
#   CuGr>Gr>GdD (dbl), CuGr>Gr>GuD (dbl), CuGr>GuAlD (dbl), CuGr>GuCpD (dbl),
#   CuGr>GuCtD (dbl), CuGr>GuD (dbl), CuGr>GuDrD (dbl), CuGuAdGaD (dbl),
#   CuGuAdGdD (dbl), CuGuAdGuD (dbl), CuGuAeGaD (dbl), CuGuAeGdD (dbl), CuGuAeGuD
#   (dbl), CuGuAlD (dbl), CuGuAlDrD (dbl), CuGuAuGaD (dbl), CuGuAuGdD (dbl),
#   CuGuAuGuD (dbl), CuGuCbGaD (dbl), CuGuCbGdD (dbl), CuGuCbGuD (dbl), CuGuCdGaD
#   (dbl), CuGuCdGdD (dbl), CuGuCdGuD (dbl), CuGuCpD (dbl), CuGuCpDrD (dbl),
#   CuGuCrCpD (dbl), CuGuCrCtD (dbl), CuGuCtD (dbl), CuGuCtDrD (dbl), CuGuCuGaD
#   (dbl), CuGuCuGdD (dbl), CuGuCuGuD (dbl), CuGuD (dbl), CuGuDaGaD (dbl),
#   CuGuDaGdD (dbl), CuGuDaGuD (dbl), CuGuDdGaD (dbl), CuGuDdGdD (dbl), CuGuDdGuD
#   (dbl), CuGuDlAlD (dbl), CuGuDpCpD (dbl), CuGuDpCtD (dbl), CuGuDpSpD (dbl),
#   CuGuDrD (dbl), CuGuDrDrD (dbl), CuGuDtCpD (dbl), CuGuDtCtD (dbl), CuGuDuGaD
#   (dbl), CuGuDuGdD (dbl), CuGuDuGuD (dbl)

# %%
prior_df = feature_df %>%
  dplyr::mutate(prior_logit = boot::logit(prior_prob)) %>%
  dplyr::select(prior_logit)
degree_df = feature_df[, colnames(feature_df) %in% degrees]
dwpc_df = feature_df[, colnames(feature_df) %in% metapaths]
head(prior_df, 2)
head(degree_df, 2)
head(dwpc_df, 2)
# Out:
# Source: local data frame [2 x 1]
#
#   prior_logit
#         (dbl)
# 1   -4.615442
# 2   -4.615442
# Source: local data frame [2 x 16]
#
#     CbG  CcSE   CdG  CiPC   CpD   CrC   CtD   CuG   DaG   DdG   DlA   DpC   DpS
#   (int) (int) (int) (int) (int) (int) (int) (int) (int) (int) (int) (int) (int)
# 1     2   249     0     1     0     7     2     1    49   143    37     2    40
# 2     7    30     0     1     0     7     2     0    49   143    37     2    40
# Variables not shown: DrD (int), DtC (int), DuG (int)
# Source: local data frame [2 x 1,196]
#
#   CbG<rG<rGaD CbG<rG<rGdD CbG<rG<rGuD CbG<rGaD CbG<rGaDrD CbG<rGbCpD CbG<rGbCtD
#         (dbl)       (dbl)       (dbl)    (dbl)      (dbl)      (dbl)      (dbl)
# 1  0.0000e+00  0.00000000  0.00000000        0 0.00000000          0          0
# 2  7.3593e-05  0.00027852  0.00063053        0 0.00025442          0          0
# Variables not shown: CbG<rGcGaD (dbl), CbG<rGcGdD (dbl), CbG<rGcGuD (dbl),
#   CbG<rGdAlD (dbl), CbG<rGdCpD (dbl), CbG<rGdCtD (dbl), CbG<rGdD (dbl),
#   CbG<rGdDrD (dbl), CbG<rGeAlD (dbl), CbG<rGiGaD (dbl), CbG<rGiGdD (dbl),
#   CbG<rGiGuD (dbl), CbG<rGr>GaD (dbl), CbG<rGr>GdD (dbl), CbG<rGr>GuD (dbl),
#   CbG<rGuAlD (dbl), CbG<rGuCpD (dbl), CbG<rGuCtD (dbl), CbG<rGuD (dbl),
#   CbG<rGuDrD (dbl), CbGaD (dbl), CbGaDaGaD (dbl), CbGaDaGdD (dbl), CbGaDaGuD
#   (dbl), CbGaDdGaD (dbl), CbGaDdGdD (dbl), CbGaDdGuD (dbl), CbGaDlAlD (dbl),
#   CbGaDpCpD (dbl), CbGaDpCtD (dbl), CbGaDpSpD (dbl), CbGaDrD (dbl), CbGaDrDrD
#   (dbl), CbGaDtCpD (dbl), CbGaDtCtD (dbl), CbGaDuGaD (dbl), CbGaDuGdD (dbl),
#   CbGaDuGuD (dbl), CbGbCbGaD (dbl), CbGbCbGdD (dbl), CbGbCbGuD (dbl), CbGbCdGaD
#   (dbl), CbGbCdGdD (dbl), CbGbCdGuD (dbl), CbGbCpD (dbl), CbGbCpDrD (dbl),
#   CbGbCrCpD (dbl), CbGbCrCtD (dbl), CbGbCtD (dbl), CbGbCtDrD (dbl), CbGbCuGaD
#   (dbl), CbGbCuGdD (dbl), CbGbCuGuD (dbl), CbGcG<rGaD (dbl), CbGcG<rGdD (dbl),
#   CbGcG<rGuD (dbl), CbGcGaD (dbl), CbGcGaDrD (dbl), CbGcGbCpD (dbl), CbGcGbCtD
#   (dbl), CbGcGcGaD (dbl), CbGcGcGdD (dbl), CbGcGcGuD (dbl), CbGcGdAlD (dbl),
#   CbGcGdCpD (dbl), CbGcGdCtD (dbl), CbGcGdD (dbl), CbGcGdDrD (dbl), CbGcGeAlD
#   (dbl), CbGcGiGaD (dbl), CbGcGiGdD (dbl), CbGcGiGuD (dbl), CbGcGr>GaD (dbl),
#   (dbl), CbGr>GbCpD (dbl), CbGr>GbCtD (dbl), CbGr>GcGaD (dbl), CbGr>GcGdD
#   (dbl), CbGr>GcGuD (dbl), CbGr>GdAlD (dbl), CbGr>GdCpD (dbl), CbGr>GdCtD
#   (dbl), CbGr>GdD (dbl), CbGr>GdDrD (dbl), CbGr>GeAlD (dbl), CbGr>GiGaD (dbl),
#   CbGr>GiGdD (dbl), CbGr>GiGuD (dbl), CbGr>Gr>GaD (dbl), CbGr>Gr>GdD (dbl),
#   CbGr>Gr>GuD (dbl), CbGr>GuAlD (dbl), CbGr>GuCpD (dbl), CbGr>GuCtD (dbl),
#   CbGr>GuD (dbl), CbGr>GuDrD (dbl), CbGuAdGaD (dbl), CbGuAdGdD (dbl), CbGuAdGuD
#   (dbl), CbGuAeGaD (dbl), CbGuAeGdD (dbl), CbGuAeGuD (dbl), CbGuAlD (dbl),
#   CbGuAlDrD (dbl), CbGuAuGaD (dbl), CbGuAuGdD (dbl), CbGuAuGuD (dbl), CbGuCbGaD
#   (dbl), CbGuCbGdD (dbl), CbGuCbGuD (dbl), CbGuCdGaD (dbl), CbGuCdGdD (dbl),
#   CbGuCdGuD (dbl), CbGuCpD (dbl), CbGuCpDrD (dbl), CbGuCrCpD (dbl), CbGuCrCtD
#   (dbl), CbGuCtD (dbl), CbGuCtDrD (dbl), CbGuCuGaD (dbl), CbGuCuGdD (dbl),
#   CbGuCuGuD (dbl), CbGuD (dbl), CbGuDaGaD (dbl), CbGuDaGdD (dbl), CbGuDaGuD
#   (dbl), CbGuDdGaD (dbl), CbGuDdGdD (dbl), CbGuDdGuD (dbl), CbGuDlAlD (dbl),
#   CbGuDpCpD (dbl), CbGuDpCtD (dbl), CbGuDpSpD (dbl), CbGuDrD (dbl), CbGuDrDrD
#   (dbl), CbGuDtCpD (dbl), CbGuDtCtD (dbl), CbGuDuGaD (dbl), CbGuDuGdD (dbl),
#   CbGuDuGuD (dbl), CcSEcCbGaD (dbl), CcSEcCbGdD (dbl), CcSEcCbGuD (dbl),
#   CcSEcCdGaD (dbl), CcSEcCdGdD (dbl), CcSEcCdGuD (dbl), CcSEcCpD (dbl),
#   CcSEcCpDrD (dbl), CcSEcCrCpD (dbl), CcSEcCrCtD (dbl), CcSEcCtD (dbl),
#   CcSEcCtDrD (dbl), CcSEcCuGaD (dbl), CcSEcCuGdD (dbl), CcSEcCuGuD (dbl),
#   CdG<rG<rGaD (dbl), CdG<rG<rGdD (dbl), CdG<rG<rGuD (dbl), CdG<rGaD (dbl),
#   CdG<rGaDrD (dbl), CdG<rGbCpD (dbl), CdG<rGbCtD (dbl), CdG<rGcGaD (dbl),
#   CdG<rGcGdD (dbl), CdG<rGcGuD (dbl), CdG<rGdAlD (dbl), CdG<rGdCpD (dbl),
#   CdG<rGdCtD (dbl), CdG<rGdD (dbl), CdG<rGdDrD (dbl), CdG<rGiGaD (dbl),
#   CdG<rGiGdD (dbl), CdG<rGiGuD (dbl), CdG<rGr>GaD (dbl), CdG<rGr>GdD (dbl),
#   CdG<rGr>GuD (dbl), CdG<rGuAlD (dbl), CdG<rGuCpD (dbl), CdG<rGuCtD (dbl),
#   CdG<rGuD (dbl), CdG<rGuDrD (dbl), CdGaD (dbl), CdGaDaGaD (dbl), CdGaDaGdD
#   (dbl), CdGaDaGuD (dbl), CdGaDdGaD (dbl), CdGaDdGdD (dbl), CdGaDdGuD (dbl),
#   CdGaDlAlD (dbl), CdGaDpCpD (dbl), CdGaDpCtD (dbl), CdGaDpSpD (dbl), CdGaDrD
#   (dbl), CdGaDrDrD (dbl), CdGaDtCpD (dbl), CdGaDtCtD (dbl), CdGaDuGaD (dbl),
#   CdGaDuGdD (dbl), CdGaDuGuD (dbl), CdGbCbGaD (dbl), CdGbCbGdD (dbl), CdGbCbGuD
#   (dbl), CdGbCdGaD (dbl), CdGbCdGdD (dbl), CdGbCdGuD (dbl), CdGbCpD (dbl),
#   CdGbCpDrD (dbl), CdGbCrCpD (dbl), CdGbCrCtD (dbl), CdGbCtD (dbl), CdGbCtDrD
#   (dbl), CdGbCuGaD (dbl), CdGbCuGdD (dbl), CdGbCuGuD (dbl), CdGcG<rGaD (dbl),
#   CdGcG<rGdD (dbl), CdGcG<rGuD (dbl), CdGcGaD (dbl), CdGcGaDrD (dbl), CdGcGbCpD
#   (dbl), CdGcGbCtD (dbl), CdGcGcGaD (dbl), CdGcGcGdD (dbl), CdGcGcGuD (dbl),
#   CdGcGdAlD (dbl), CdGcGdCpD (dbl), CdGcGdCtD (dbl), CdGcGdD (dbl), CdGcGdDrD
#   (dbl), CdGcGeAlD (dbl), CdGcGiGaD (dbl), CdGcGiGdD (dbl), CdGcGiGuD (dbl),
#   CdGcGr>GaD (dbl), CdGcGr>GdD (dbl), CdGcGr>GuD (dbl), CdGcGuAlD (dbl),
#   CdGcGuCpD (dbl), CdGcGuCtD (dbl), CdGcGuD (dbl), CdGcGuDrD (dbl), CdGdAdGaD
#   (dbl), CdGdAdGdD (dbl), CdGdAdGuD (dbl), CdGdAeGaD (dbl), CdGdAeGdD (dbl),
#   CdGdAeGuD (dbl), CdGdAlD (dbl), CdGdAlDrD (dbl), CdGdAuGaD (dbl), CdGdAuGdD
#   (dbl), CdGdAuGuD (dbl), CdGdCbGaD (dbl), CdGdCbGdD (dbl), CdGdCbGuD (dbl),
#   CdGdCdGaD (dbl), CdGdCdGdD (dbl), CdGdCdGuD (dbl), CdGdCpD (dbl), CdGdCpDrD
#   (dbl), CdGdCrCpD (dbl), CdGdCrCtD (dbl), CdGdCtD (dbl), CdGdCtDrD (dbl),
#   CdGdCuGaD (dbl), CdGdCuGdD (dbl), CdGdCuGuD (dbl), CdGdD (dbl), CdGdDaGaD
#   (dbl), CdGdDaGdD (dbl), CdGdDaGuD (dbl), CdGdDdGaD (dbl), CdGdDdGdD (dbl),
#   CdGdDdGuD (dbl), CdGdDlAlD (dbl), CdGdDpCpD (dbl), CdGdDpCtD (dbl), CdGdDpSpD
#   (dbl), CdGdDrD (dbl), CdGdDrDrD (dbl), CdGdDtCpD (dbl), CdGdDtCtD (dbl),
#   CdGdDuGaD (dbl), CdGdDuGdD (dbl), CdGdDuGuD (dbl), CdGeAdGaD (dbl), CdGeAdGdD
#   (dbl), CdGeAdGuD (dbl), CdGeAlD (dbl), CdGeAlDrD (dbl), CdGeAuGaD (dbl),
#   CdGeAuGdD (dbl), CdGeAuGuD (dbl), CdGiG<rGaD (dbl), CdGiG<rGdD (dbl),
#   CdGiG<rGuD (dbl), CdGiGaD (dbl), CdGiGaDrD (dbl), CdGiGbCpD (dbl), CdGiGbCtD
#   (dbl), CdGiGcGaD (dbl), CdGiGcGdD (dbl), CdGiGcGuD (dbl), CdGiGdAlD (dbl),
#   CdGiGdCpD (dbl), CdGiGdCtD (dbl), CdGiGdD (dbl), CdGiGdDrD (dbl), CdGiGeAlD
#   (dbl), CdGiGiGaD (dbl), CdGiGiGdD (dbl), CdGiGiGuD (dbl), CdGiGr>GaD (dbl),
#   CdGiGr>GdD (dbl), CdGiGr>GuD (dbl), CdGiGuAlD (dbl), CdGiGuCpD (dbl),
#   CdGiGuCtD (dbl), CdGiGuD (dbl), CdGiGuDrD (dbl), CdGpBPpGaD (dbl), CdGpBPpGdD
#   (dbl), CdGpBPpGuD (dbl), CdGpCCpGaD (dbl), CdGpCCpGdD (dbl), CdGpCCpGuD
#   (dbl), CdGpMFpGaD (dbl), CdGpMFpGdD (dbl), CdGpMFpGuD (dbl), CdGpPWpGaD
#   (dbl), CdGpPWpGdD (dbl), CdGpPWpGuD (dbl), CdGr>G<rGaD (dbl), CdGr>G<rGdD
#   (dbl), CdGr>G<rGuD (dbl), CdGr>GaD (dbl), CdGr>GaDrD (dbl), CdGr>GbCpD (dbl),
#   CdGr>GbCtD (dbl), CdGr>GcGaD (dbl), CdGr>GcGdD (dbl), CdGr>GcGuD (dbl),
#   CdGr>GdAlD (dbl), CdGr>GdCpD (dbl), CdGr>GdCtD (dbl), CdGr>GdD (dbl),
#   CdGr>GdDrD (dbl), CdGr>GeAlD (dbl), CdGr>GiGaD (dbl), CdGr>GiGdD (dbl),
#   CdGr>GiGuD (dbl), CdGr>Gr>GaD (dbl), CdGr>Gr>GdD (dbl), CdGr>Gr>GuD (dbl),
#   CdGr>GuAlD (dbl), CdGr>GuCpD (dbl), CdGr>GuCtD (dbl), CdGr>GuD (dbl),
#   CdGr>GuDrD (dbl), CdGuAdGaD (dbl), CdGuAdGdD (dbl), CdGuAdGuD (dbl),
#   CdGuAeGaD (dbl), CdGuAeGdD (dbl), CdGuAeGuD (dbl), CdGuAlD (dbl), CdGuAlDrD
#   (dbl), CdGuAuGaD (dbl), CdGuAuGdD (dbl), CdGuAuGuD (dbl), CdGuCbGaD (dbl),
#   CdGuCbGdD (dbl), CdGuCbGuD (dbl), CdGuCdGaD (dbl), CdGuCdGdD (dbl), CdGuCdGuD
#   (dbl), CdGuCpD (dbl), CdGuCpDrD (dbl), CdGuCrCpD (dbl), CdGuCrCtD (dbl),
#   CdGuCtD (dbl), CdGuCtDrD (dbl), CdGuCuGaD (dbl), CdGuCuGdD (dbl), CdGuCuGuD
#   (dbl), CdGuD (dbl), CdGuDaGaD (dbl), CdGuDaGdD (dbl), CdGuDaGuD (dbl),
#   CdGuDdGaD (dbl), CdGuDdGdD (dbl), CdGuDdGuD (dbl), CdGuDlAlD (dbl), CdGuDpCpD
#   (dbl), CdGuDpCtD (dbl), CdGuDpSpD (dbl), CdGuDrD (dbl), CdGuDrDrD (dbl),
#   CdGuDtCpD (dbl), CdGuDtCtD (dbl), CdGuDuGaD (dbl), CdGuDuGdD (dbl), CdGuDuGuD
#   (dbl), CiPCiCbGaD (dbl), CiPCiCbGdD (dbl), CiPCiCbGuD (dbl), CiPCiCdGaD
#   (dbl), CiPCiCdGdD (dbl), CiPCiCdGuD (dbl), CiPCiCpD (dbl), CiPCiCpDrD (dbl),
#   CiPCiCrCpD (dbl), CiPCiCrCtD (dbl), CiPCiCtD (dbl), CiPCiCtDrD (dbl),
#   CiPCiCuGaD (dbl), CiPCiCuGdD (dbl), CiPCiCuGuD (dbl), CpDaG<rGaD (dbl),
#   CpDaG<rGdD (dbl), CpDaG<rGuD (dbl), CpDaGaD (dbl), CpDaGaDrD (dbl), CpDaGbCpD
#   (dbl), CpDaGbCtD (dbl), CpDaGcGaD (dbl), CpDaGcGdD (dbl), CpDaGcGuD (dbl),
#   CpDaGdAlD (dbl), CpDaGdCpD (dbl), CpDaGdCtD (dbl), CpDaGdD (dbl), CpDaGdDrD
#   (dbl), CpDaGeAlD (dbl), CpDaGiGaD (dbl), CpDaGiGdD (dbl), CpDaGiGuD (dbl),
#   CpDaGr>GaD (dbl), CpDaGr>GdD (dbl), CpDaGr>GuD (dbl), CpDaGuAlD (dbl),
#   CpDaGuCpD (dbl), CpDaGuCtD (dbl), CpDaGuD (dbl), CpDaGuDrD (dbl), CpDdG<rGaD
#   (dbl), CpDdG<rGdD (dbl), CpDdG<rGuD (dbl), CpDdGaD (dbl), CpDdGaDrD (dbl),
#   CpDdGbCpD (dbl), CpDdGbCtD (dbl), CpDdGcGaD (dbl), CpDdGcGdD (dbl), CpDdGcGuD
#   (dbl), CpDdGdAlD (dbl), CpDdGdCpD (dbl), CpDdGdCtD (dbl), CpDdGdD (dbl),
#   CpDdGdDrD (dbl), CpDdGeAlD (dbl), CpDdGiGaD (dbl), CpDdGiGdD (dbl), CpDdGiGuD
#   (dbl), CpDdGr>GaD (dbl), CpDdGr>GdD (dbl), CpDdGr>GuD (dbl), CpDdGuAlD (dbl),
#   CpDdGuCpD (dbl), CpDdGuCtD (dbl), CpDdGuD (dbl), CpDdGuDrD (dbl), CpDlAdGaD
#   (dbl), CpDlAdGdD (dbl), CpDlAdGuD (dbl), CpDlAeGaD (dbl), CpDlAeGdD (dbl),
#   CpDlAeGuD (dbl), CpDlAlD (dbl), CpDlAlDrD (dbl), CpDlAuGaD (dbl), CpDlAuGdD
#   (dbl), CpDlAuGuD (dbl), CpDpCbGaD (dbl), CpDpCbGdD (dbl), CpDpCbGuD (dbl),
#   CpDpCdGaD (dbl), CpDpCdGdD (dbl), CpDpCdGuD (dbl), CpDpCpD (dbl), CpDpCpDrD
#   (dbl), CpDpCrCpD (dbl), CpDpCrCtD (dbl), CpDpCtD (dbl), CpDpCtDrD (dbl),
#   CpDpCuGaD (dbl), CpDpCuGdD (dbl), CpDpCuGuD (dbl), CpDpSpD (dbl), CpDpSpDrD
#   (dbl), CpDrD (dbl), CpDrDaGaD (dbl), CpDrDaGdD (dbl), CpDrDaGuD (dbl),
#   CpDrDdGaD (dbl), CpDrDdGdD (dbl), CpDrDdGuD (dbl), CpDrDlAlD (dbl), CpDrDpCpD
#   (dbl), CpDrDpCtD (dbl), CpDrDpSpD (dbl), CpDrDrD (dbl), CpDrDrDrD (dbl),
#   CpDrDtCpD (dbl), CpDrDtCtD (dbl), CpDrDuGaD (dbl), CpDrDuGdD (dbl), CpDrDuGuD
#   (dbl), CpDtCbGaD (dbl), CpDtCbGdD (dbl), CpDtCbGuD (dbl), CpDtCdGaD (dbl),
#   CpDtCdGdD (dbl), CpDtCdGuD (dbl), CpDtCpD (dbl), CpDtCpDrD (dbl), CpDtCrCpD
#   (dbl), CpDtCrCtD (dbl), CpDtCtD (dbl), CpDtCtDrD (dbl), CpDtCuGaD (dbl),
#   CpDtCuGdD (dbl), CpDtCuGuD (dbl), CpDuG<rGaD (dbl), CpDuG<rGdD (dbl),
#   CpDuG<rGuD (dbl), CpDuGaD (dbl), CpDuGaDrD (dbl), CpDuGbCpD (dbl), CpDuGbCtD
#   (dbl), CpDuGcGaD (dbl), CpDuGcGdD (dbl), CpDuGcGuD (dbl), CpDuGdAlD (dbl),
#   CpDuGdCpD (dbl), CpDuGdCtD (dbl), CpDuGdD (dbl), CpDuGdDrD (dbl), CpDuGeAlD
#   (dbl), CpDuGiGaD (dbl), CpDuGiGdD (dbl), CpDuGiGuD (dbl), CpDuGr>GaD (dbl),
#   CpDuGr>GdD (dbl), CpDuGr>GuD (dbl), CpDuGuAlD (dbl), CpDuGuCpD (dbl),
#   CpDuGuCtD (dbl), CpDuGuD (dbl), CpDuGuDrD (dbl), CrCbG<rGaD (dbl), CrCbG<rGdD
#   (dbl), CrCbG<rGuD (dbl), CrCbGaD (dbl), CrCbGaDrD (dbl), CrCbGbCpD (dbl),
#   CrCbGbCtD (dbl), CrCbGcGaD (dbl), CrCbGcGdD (dbl), CrCbGcGuD (dbl), CrCbGdAlD
#   (dbl), CrCbGdCpD (dbl), CrCbGdCtD (dbl), CrCbGdD (dbl), CrCbGdDrD (dbl),
#   CrCbGeAlD (dbl), CrCbGiGaD (dbl), CrCbGiGdD (dbl), CrCbGiGuD (dbl),
#   CrCbGr>GaD (dbl), CrCbGr>GdD (dbl), CrCbGr>GuD (dbl), CrCbGuAlD (dbl),
#   CrCbGuCpD (dbl), CrCbGuCtD (dbl), CrCbGuD (dbl), CrCbGuDrD (dbl), CrCcSEcCpD
#   (dbl), CrCcSEcCtD (dbl), CrCdG<rGaD (dbl), CrCdG<rGdD (dbl), CrCdG<rGuD
#   (dbl), CrCdGaD (dbl), CrCdGaDrD (dbl), CrCdGbCpD (dbl), CrCdGbCtD (dbl),
#   CrCdGcGaD (dbl), CrCdGcGdD (dbl), CrCdGcGuD (dbl), CrCdGdAlD (dbl), CrCdGdCpD
#   (dbl), CrCdGdCtD (dbl), CrCdGdD (dbl), CrCdGdDrD (dbl), CrCdGeAlD (dbl),
#   CrCdGiGaD (dbl), CrCdGiGdD (dbl), CrCdGiGuD (dbl), CrCdGr>GaD (dbl),
#   CrCdGr>GdD (dbl), CrCdGr>GuD (dbl), CrCdGuAlD (dbl), CrCdGuCpD (dbl),
#   CrCdGuCtD (dbl), CrCdGuD (dbl), CrCdGuDrD (dbl), CrCiPCiCpD (dbl), CrCiPCiCtD
#   (dbl), CrCpD (dbl), CrCpDaGaD (dbl), CrCpDaGdD (dbl), CrCpDaGuD (dbl),
#   CrCpDdGaD (dbl), CrCpDdGdD (dbl), CrCpDdGuD (dbl), CrCpDlAlD (dbl), CrCpDpCpD
#   (dbl), CrCpDpCtD (dbl), CrCpDpSpD (dbl), CrCpDrD (dbl), CrCpDrDrD (dbl),
#   CrCpDtCpD (dbl), CrCpDtCtD (dbl), CrCpDuGaD (dbl), CrCpDuGdD (dbl), CrCpDuGuD
#   (dbl), CrCrCbGaD (dbl), CrCrCbGdD (dbl), CrCrCbGuD (dbl), CrCrCdGaD (dbl),
#   CrCrCdGdD (dbl), CrCrCdGuD (dbl), CrCrCpD (dbl), CrCrCpDrD (dbl), CrCrCrCpD
#   (dbl), CrCrCrCtD (dbl), CrCrCtD (dbl), CrCrCtDrD (dbl), CrCrCuGaD (dbl),
#   CrCrCuGdD (dbl), CrCrCuGuD (dbl), CrCtD (dbl), CrCtDaGaD (dbl), CrCtDaGdD
#   (dbl), CrCtDaGuD (dbl), CrCtDdGaD (dbl), CrCtDdGdD (dbl), CrCtDdGuD (dbl),
#   CrCtDlAlD (dbl), CrCtDpCpD (dbl), CrCtDpCtD (dbl), CrCtDpSpD (dbl), CrCtDrD
#   (dbl), CrCtDrDrD (dbl), CrCtDtCpD (dbl), CrCtDtCtD (dbl), CrCtDuGaD (dbl),
#   CrCtDuGdD (dbl), CrCtDuGuD (dbl), CrCuG<rGaD (dbl), CrCuG<rGdD (dbl),
#   CrCuG<rGuD (dbl), CrCuGaD (dbl), CrCuGaDrD (dbl), CrCuGbCpD (dbl), CrCuGbCtD
#   (dbl), CrCuGcGaD (dbl), CrCuGcGdD (dbl), CrCuGcGuD (dbl), CrCuGdAlD (dbl),
#   CrCuGdCpD (dbl), CrCuGdCtD (dbl), CrCuGdD (dbl), CrCuGdDrD (dbl), CrCuGeAlD
#   (dbl), CrCuGiGaD (dbl), CrCuGiGdD (dbl), CrCuGiGuD (dbl), CrCuGr>GaD (dbl),
#   CrCuGr>GdD (dbl), CrCuGr>GuD (dbl), CrCuGuAlD (dbl), CrCuGuCpD (dbl),
#   CrCuGuCtD (dbl), CrCuGuD (dbl), CrCuGuDrD (dbl), CtDaG<rGaD (dbl), CtDaG<rGdD
#   (dbl), CtDaG<rGuD (dbl), CtDaGaD (dbl), CtDaGaDrD (dbl), CtDaGbCpD (dbl),
#   CtDaGbCtD (dbl), CtDaGcGaD (dbl), CtDaGcGdD (dbl), CtDaGcGuD (dbl), CtDaGdAlD
#   (dbl), CtDaGdCpD (dbl), CtDaGdCtD (dbl), CtDaGdD (dbl), CtDaGdDrD (dbl),
#   CtDaGeAlD (dbl), CtDaGiGaD (dbl), CtDaGiGdD (dbl), CtDaGiGuD (dbl),
#   CtDaGr>GaD (dbl), CtDaGr>GdD (dbl), CtDaGr>GuD (dbl), CtDaGuAlD (dbl),
#   CtDaGuCpD (dbl), CtDaGuCtD (dbl), CtDaGuD (dbl), CtDaGuDrD (dbl), CtDdG<rGaD
#   (dbl), CtDdG<rGdD (dbl), CtDdG<rGuD (dbl), CtDdGaD (dbl), CtDdGaDrD (dbl),
#   CtDdGbCpD (dbl), CtDdGbCtD (dbl), CtDdGcGaD (dbl), CtDdGcGdD (dbl), CtDdGcGuD
#   (dbl), CtDdGdAlD (dbl), CtDdGdCpD (dbl), CtDdGdCtD (dbl), CtDdGdD (dbl),
#   CtDdGdDrD (dbl), CtDdGeAlD (dbl), CtDdGiGaD (dbl), CtDdGiGdD (dbl), CtDdGiGuD
#   (dbl), CtDdGr>GaD (dbl), CtDdGr>GdD (dbl), CtDdGr>GuD (dbl), CtDdGuAlD (dbl),
#   CtDdGuCpD (dbl), CtDdGuCtD (dbl), CtDdGuD (dbl), CtDdGuDrD (dbl), CtDlAdGaD
#   (dbl), CtDlAdGdD (dbl), CtDlAdGuD (dbl), CtDlAeGaD (dbl), CtDlAeGdD (dbl),
#   CtDlAeGuD (dbl), CtDlAlD (dbl), CtDlAlDrD (dbl), CtDlAuGaD (dbl), CtDlAuGdD
#   (dbl), CtDlAuGuD (dbl), CtDpCbGaD (dbl), CtDpCbGdD (dbl), CtDpCbGuD (dbl),
#   CtDpCdGaD (dbl), CtDpCdGdD (dbl), CtDpCdGuD (dbl), CtDpCpD (dbl), CtDpCpDrD
#   (dbl), CtDpCrCpD (dbl), CtDpCrCtD (dbl), CtDpCtD (dbl), CtDpCtDrD (dbl),
#   CtDpCuGaD (dbl), CtDpCuGdD (dbl), CtDpCuGuD (dbl), CtDpSpD (dbl), CtDpSpDrD
#   (dbl), CtDrD (dbl), CtDrDaGaD (dbl), CtDrDaGdD (dbl), CtDrDaGuD (dbl),
#   CtDrDdGaD (dbl), CtDrDdGdD (dbl), CtDrDdGuD (dbl), CtDrDlAlD (dbl), CtDrDpCpD
#   (dbl), CtDrDpCtD (dbl), CtDrDpSpD (dbl), CtDrDrD (dbl), CtDrDrDrD (dbl),
#   CtDrDtCpD (dbl), CtDrDtCtD (dbl), CtDrDuGaD (dbl), CtDrDuGdD (dbl), CtDrDuGuD
#   (dbl), CtDtCbGaD (dbl), CtDtCbGdD (dbl), CtDtCbGuD (dbl), CtDtCdGaD (dbl),
#   CtDtCdGdD (dbl), CtDtCdGuD (dbl), CtDtCpD (dbl), CtDtCpDrD (dbl), CtDtCrCpD
#   (dbl), CtDtCrCtD (dbl), CtDtCtD (dbl), CtDtCtDrD (dbl), CtDtCuGaD (dbl),
#   (dbl), CuGr>GaDrD (dbl), CuGr>GbCpD (dbl), CuGr>GbCtD (dbl), CuGr>GcGaD
#   (dbl), CuGr>GcGdD (dbl), CuGr>GcGuD (dbl), CuGr>GdAlD (dbl), CuGr>GdCpD
#   (dbl), CuGr>GdCtD (dbl), CuGr>GdD (dbl), CuGr>GdDrD (dbl), CuGr>GeAlD (dbl),
#   CuGr>GiGaD (dbl), CuGr>GiGdD (dbl), CuGr>GiGuD (dbl), CuGr>Gr>GaD (dbl),
#   CuGr>Gr>GdD (dbl), CuGr>Gr>GuD (dbl), CuGr>GuAlD (dbl), CuGr>GuCpD (dbl),
#   CuGr>GuCtD (dbl), CuGr>GuD (dbl), CuGr>GuDrD (dbl), CuGuAdGaD (dbl),
#   CuGuAdGdD (dbl), CuGuAdGuD (dbl), CuGuAeGaD (dbl), CuGuAeGdD (dbl), CuGuAeGuD
#   (dbl), CuGuAlD (dbl), CuGuAlDrD (dbl), CuGuAuGaD (dbl), CuGuAuGdD (dbl),
#   CuGuAuGuD (dbl), CuGuCbGaD (dbl), CuGuCbGdD (dbl), CuGuCbGuD (dbl), CuGuCdGaD
#   (dbl), CuGuCdGdD (dbl), CuGuCdGuD (dbl), CuGuCpD (dbl), CuGuCpDrD (dbl),
#   CuGuCrCpD (dbl), CuGuCrCtD (dbl), CuGuCtD (dbl), CuGuCtDrD (dbl), CuGuCuGaD
#   (dbl), CuGuCuGdD (dbl), CuGuCuGuD (dbl), CuGuD (dbl), CuGuDaGaD (dbl),
#   CuGuDaGdD (dbl), CuGuDaGuD (dbl), CuGuDdGaD (dbl), CuGuDdGdD (dbl), CuGuDdGuD
#   (dbl), CuGuDlAlD (dbl), CuGuDpCpD (dbl), CuGuDpCtD (dbl), CuGuDpSpD (dbl),
#   CuGuDrD (dbl), CuGuDrDrD (dbl), CuGuDtCpD (dbl), CuGuDtCtD (dbl), CuGuDuGaD
#   (dbl), CuGuDuGdD (dbl), CuGuDuGuD (dbl)

# %% [markdown]
# ## Prior probability distributions

# %%
options(repr.plot.width=6, repr.plot.height=3)

feature_df %>%
  dplyr::mutate(prior_logit = boot::logit(prior_prob)) %>%
  dplyr::select(prior_prob, prior_logit) %>%
  tidyr::gather('feature', 'value') %>%
  ggplot2::ggplot(ggplot2::aes(x = value)) +
    ggplot2::facet_wrap(~ feature, scales='free') +
    ggplot2::geom_histogram(bins = 50, alpha = 0.6, fill = '#00693E') +
    ggplot2::theme_bw() +
    ggplot2::theme(strip.background=ggplot2::element_rect(fill='#FEF2E2')) +
    ggplot2::theme(plot.margin=grid::unit(c(2, 7, 2, 2), 'points')) +
    ggplot2::ylab(NULL)
# Out:
# plot without title

# %% [markdown]
# ## Visualize degree features

# %%
set.seed(0)
dist_df = summary_df %>%
  dplyr::filter(feature_type == 'degree') %>%
  dplyr::mutate(nonzero_quantile = dplyr::ntile(nonzero, 10)) %>%
  dplyr::group_by(nonzero_quantile) %>%
  dplyr::sample_n(1) %>%
  dplyr::arrange(nonzero) %>%
  dplyr::select(feature, nonzero, nonzero_quantile)

# %%
example_df = degree_df %>%
  dplyr::select(one_of(dist_df$feature)) %>%
  tidyr::gather(key = feature, value = value) %>%
  dplyr::inner_join(dist_df) %>%
  dplyr::mutate(nonzero = scales::percent(nonzero))

grouped_df = example_df %>%
  dplyr::group_by(feature)

all_df = dplyr::bind_rows(
  grouped_df %>% dplyr::mutate(value = value, transform='(1) identity'),
  grouped_df %>% dplyr::mutate(value = log1p(value), transform='(2) log1p(x)'),
  grouped_df %>% dplyr::mutate(value = asinh(value), transform='(3) asinh(x)')
)

options(repr.plot.width=8, repr.plot.height=15)

all_df %>%
  ggplot2::ggplot(ggplot2::aes(x = value)) +
    ggplot2::facet_wrap(nonzero_quantile + feature ~ transform + nonzero, scales='free', ncol=3,
      labeller = ggplot2::as_labeller(I, multi_line = F)) +
    ggplot2::geom_histogram(bins = 50, alpha = 0.6, fill = '#00693E') +
    ggplot2::theme_bw() +
    ggplot2::theme(strip.background=ggplot2::element_rect(fill='#FEF2E2')) +
    ggplot2::theme(plot.margin=grid::unit(c(2, 7, 2, 2), 'points')) +
    ggplot2::xlab('Degree') + ggplot2::ylab(NULL)
# Out:
# Joining by: "feature"
# plot without title

# %% [markdown]
# ## Visualize degree features

# %%
set.seed(0)
dist_df = summary_df %>%
  dplyr::filter(feature_type == 'dwpc') %>%
  dplyr::mutate(nonzero_quantile = dplyr::ntile(nonzero, 10)) %>%
  dplyr::group_by(nonzero_quantile) %>%
  dplyr::sample_n(1) %>%
  dplyr::arrange(nonzero) %>%
  dplyr::select(feature, nonzero, nonzero_quantile)
head(dist_df, 2)
# Out:
# Source: local data frame [2 x 3]
# Groups: nonzero_quantile [2]
#
#     feature  nonzero nonzero_quantile
#       (chr)    (dbl)            (dbl)
# 1 CrCpDtCpD 0.024106                1
# 2 CpDaGiGuD 0.070199                2

# %%
example_df = dwpc_df %>%
  dplyr::select(one_of(dist_df$feature)) %>%
  tidyr::gather(key = feature, value = value) %>%
  dplyr::inner_join(dist_df) %>%
  dplyr::mutate(nonzero = scales::percent(nonzero))

grouped_df = example_df %>%
  dplyr::group_by(feature)

all_df = dplyr::bind_rows(
grouped_df %>% dplyr::mutate(value = value, transform='1-identity'),
grouped_df %>% dplyr::mutate(value = log1p(value / sd(value)), transform='2-log1p-sd'),
grouped_df %>% dplyr::mutate(value = log1p(value / mean(value)), transform='3-log1p-mean'),
grouped_df %>% dplyr::mutate(value = asinh(value / sd(value)), transform='4-asinh-sd'),
grouped_df %>% dplyr::mutate(value = asinh(value / mean(value)), transform='5-asinh-mean')
)

options(repr.plot.width=15, repr.plot.height=15)

all_df %>%
  dplyr::filter(value > 0) %>%
  ggplot2::ggplot(ggplot2::aes(x = value)) +
    ggplot2::facet_wrap(nonzero_quantile + feature ~ transform + nonzero, scales='free', ncol=5,
      labeller = ggplot2::as_labeller(I, multi_line = F)) +
    ggplot2::geom_histogram(bins = 50, alpha = 0.6, fill = '#00693E') +
    ggplot2::theme_bw() +
    ggplot2::theme(strip.background=ggplot2::element_rect(fill='#FEF2E2')) +
    ggplot2::theme(plot.margin=grid::unit(c(2, 7, 2, 2), 'points')) +
    ggplot2::xlab('DWPC (Zero-filtered)') + ggplot2::ylab(NULL) +
    ggplot2::expand_limits(x = 0)
# Out:
# Joining by: "feature"
# plot without title

# %% [markdown]
# ## Tranformation sweep

# %%
grid_df = expand.grid(
  degree_transformer = c('identity', 'log1p', 'asinh'),
  dwpc_scaler = c('none', 'mean', 'sd'),
  dwpc_transformer = c('identity', 'log1p', 'asinh'),
  alpha = c(0, 1),
  seed = 1:10,
  stringsAsFactors = FALSE
) %>% dplyr::filter(dwpc_transformer != 'identity' | dwpc_scaler == 'none')

nrow(grid_df)
# Out:
# [1] 420

# %%
none = function(x) {return(1)}

to_fxn = function(x) {eval(parse(text=x))}

get_performance = function(params) {
  # Evaluate performance of specified tranformations
  dwpc_scaler = to_fxn(params['dwpc_scaler'])
  dwpc_transformer = to_fxn(params['dwpc_transformer'])
  degree_transformer = to_fxn(params[['degree_transformer']])

  X = dplyr::bind_cols(
    prior_df,
    degree_df %>%
      dplyr::mutate(across(everything(), ~degree_transformer(.))),
    dwpc_df %>%
      dplyr::mutate(across(everything(), ~dwpc_transformer(./dwpc_scaler(.))))
  ) %>% as.matrix()
  
  y_true = feature_df$status
  penalty_factor = ifelse(colnames(X) == 'prior_logit', 0, 1)
  fit = hetior::glmnet_train(X = X, y = y_true, alpha = params['alpha'], cores = 12,
                             seed = params['seed'], penalty.factor=penalty_factor, lambda.min.ratio=1e-6, nlambda=200)
  df = data.frame(t(params), auroc = fit$vtm$auroc, auprc = fit$vtm$auprc)
  return(df)
}

perf_df = grid_df %>% apply(1, get_performance) %>% dplyr::bind_rows()
# Out:
# Loading required package: Matrix
# Loading required package: foreach
# Loaded glmnet 2.0-5

# %%
head(perf_df, 4)
# Out:
# Source: local data frame [4 x 7]
#
#   degree_transformer dwpc_scaler dwpc_transformer alpha  seed     auroc
#                (chr)       (chr)            (chr) (chr) (chr)     (dbl)
# 1           identity        none         identity     0     1 0.9834933
# 2              log1p        none         identity     0     1 0.9858905
# 3              asinh        none         identity     0     1 0.9859958
# 4           identity        none            log1p     0     1 0.9836148
# Variables not shown: auprc (dbl)

# %% [markdown]
# ### Average results across seeds

# %%
summary_df = perf_df %>%
  dplyr::group_by(degree_transformer, dwpc_scaler, dwpc_transformer, alpha) %>%
  dplyr::do(
    dplyr::bind_cols(
      ggplot2::mean_cl_normal(.$auroc) %>% dplyr::rename(auroc=y, auroc_lower=ymin, auroc_upper=ymax),
      ggplot2::mean_cl_normal(.$auprc) %>% dplyr::rename(auprc=y, auprc_lower=ymin, auprc_upper=ymax))
  ) %>%
  dplyr::ungroup() %>%
  dplyr::arrange(desc(auroc))

head(summary_df, 2)
# Out:
# Source: local data frame [2 x 10]
#
#   degree_transformer dwpc_scaler dwpc_transformer alpha     auroc auroc_lower
#                (chr)       (chr)            (chr) (chr)     (dbl)       (dbl)
# 1              asinh        mean            log1p     1 0.9951390   0.9947350
# 2              asinh        mean            asinh     1 0.9949061   0.9944867
# Variables not shown: auroc_upper (dbl), auprc (dbl), auprc_lower (dbl),
#   auprc_upper (dbl)

# %%
summary_df %>% readr::write_tsv('data/transformation-sweep.tsv')
