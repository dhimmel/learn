# %% [markdown]
# # Compare model performance between real and permuted hetnets

# %%
library(magrittr)

# %%
auroc_df = readr::read_tsv('data/auroc.tsv')
degrees = dplyr::filter(auroc_df, feature_type == 'degree')$feature
metapaths = dplyr::filter(auroc_df, feature_type == 'dwpc')$feature

# col_types not needed here, but used for safety
col_types = list()
for (metapath in metapaths) {
  col_types[[metapath]] = readr::col_number()
}
for (degree in degrees) {
  col_types[[degree]] = readr::col_integer()
}

feature_df = readr::read_tsv('data/matrix/features.tsv.bz2', col_types = col_types)

# %%
transform_df = function(df) {
    
  df = dplyr::bind_cols(
    df %>%
    dplyr::transmute(status, prior_logit = boot::logit(prior_prob)),

    df %>%
    dplyr::select(one_of(degrees)) %>%
    dplyr::mutate_each(dplyr::funs(asinh)),

    df %>%
    dplyr::select(one_of(metapaths)) %>%
    dplyr::mutate_each(dplyr::funs(asinh(. / mean(.))))
  )
  return(df)
}

transformed_df = feature_df %>%
  dplyr::group_by(hetnet) %>%
  dplyr::do(transform_df(.)) %>%
  dplyr::ungroup()

head(transformed_df, 2)
# Out:
# Source: local data frame [2 x 1,215]
#
#          hetnet status prior_logit      CbG     CcSE   CdG      CiPC   CpD
#           (chr)  (int)       (dbl)    (dbl)    (dbl) (dbl)     (dbl) (dbl)
# 1 rephetio-v2.0      0   -4.615442 1.443635 6.210604     0 0.8813736     0
# 2 rephetio-v2.0      0   -4.615442 2.644121 4.094622     0 0.8813736     0
# Variables not shown: CrC (dbl), CtD (dbl), CuG (dbl), DaG (dbl), DdG (dbl), DlA
#   (dbl), DpC (dbl), DpS (dbl), DrD (dbl), DtC (dbl), DuG (dbl), CbG<rG<rGaD
#   (dbl), CbG<rG<rGdD (dbl), CbG<rG<rGuD (dbl), CbG<rGaD (dbl), CbG<rGaDrD
#   (dbl), CbG<rGbCpD (dbl), CbG<rGbCtD (dbl), CbG<rGcGaD (dbl), CbG<rGcGdD
#   (dbl), CbG<rGcGuD (dbl), CbG<rGdAlD (dbl), CbG<rGdCpD (dbl), CbG<rGdCtD
#   (dbl), CbG<rGdD (dbl), CbG<rGdDrD (dbl), CbG<rGeAlD (dbl), CbG<rGiGaD (dbl),
#   CbG<rGiGdD (dbl), CbG<rGiGuD (dbl), CbG<rGr>GaD (dbl), CbG<rGr>GdD (dbl),
#   CbG<rGr>GuD (dbl), CbG<rGuAlD (dbl), CbG<rGuCpD (dbl), CbG<rGuCtD (dbl),
#   CbG<rGuD (dbl), CbG<rGuDrD (dbl), CbGaD (dbl), CbGaDaGaD (dbl), CbGaDaGdD
#   (dbl), CbGaDaGuD (dbl), CbGaDdGaD (dbl), CbGaDdGdD (dbl), CbGaDdGuD (dbl),
#   CbGaDlAlD (dbl), CbGaDpCpD (dbl), CbGaDpCtD (dbl), CbGaDpSpD (dbl), CbGaDrD
#   (dbl), CbGaDrDrD (dbl), CbGaDtCpD (dbl), CbGaDtCtD (dbl), CbGaDuGaD (dbl),
#   CbGaDuGdD (dbl), CbGaDuGuD (dbl), CbGbCbGaD (dbl), CbGbCbGdD (dbl), CbGbCbGuD
#   (dbl), CbGbCdGaD (dbl), CbGbCdGdD (dbl), CbGbCdGuD (dbl), CbGbCpD (dbl),
#   CbGbCpDrD (dbl), CbGbCrCpD (dbl), CbGbCrCtD (dbl), CbGbCtD (dbl), CbGbCtDrD
#   (dbl), CbGbCuGaD (dbl), CbGbCuGdD (dbl), CbGbCuGuD (dbl), CbGcG<rGaD (dbl),
#   CbGcG<rGdD (dbl), CbGcG<rGuD (dbl), CbGcGaD (dbl), CbGcGaDrD (dbl), CbGcGbCpD
#   (dbl), CbGcGbCtD (dbl), CbGcGcGaD (dbl), CbGcGcGdD (dbl), CbGcGcGuD (dbl),
#   CbGcGdAlD (dbl), CbGcGdCpD (dbl), CbGcGdCtD (dbl), CbGcGdD (dbl), CbGcGdDrD
#   (dbl), CbGcGeAlD (dbl), CbGcGiGaD (dbl), CbGcGiGdD (dbl), CbGcGiGuD (dbl),
#   CbGcGr>GaD (dbl), CbGcGr>GdD (dbl), CbGcGr>GuD (dbl), CbGcGuAlD (dbl),
#   CbGcGuCpD (dbl), CbGcGuCtD (dbl), CbGcGuD (dbl), CbGcGuDrD (dbl), CbGdAdGaD
#   (dbl), CbGdAdGdD (dbl), CbGdAdGuD (dbl), CbGdAeGaD (dbl), CbGdAeGdD (dbl),
#   CbGdAeGuD (dbl), CbGdAlD (dbl), CbGdAlDrD (dbl), CbGdAuGaD (dbl), CbGdAuGdD
#   (dbl), CbGdAuGuD (dbl), CbGdCbGaD (dbl), CbGdCbGdD (dbl), CbGdCbGuD (dbl),
#   CbGdCdGaD (dbl), CbGdCdGdD (dbl), CbGdCdGuD (dbl), CbGdCpD (dbl), CbGdCpDrD
#   (dbl), CbGdCrCpD (dbl), CbGdCrCtD (dbl), CbGdCtD (dbl), CbGdCtDrD (dbl),
#   CbGdCuGaD (dbl), CbGdCuGdD (dbl), CbGdCuGuD (dbl), CbGdD (dbl), CbGdDaGaD
#   (dbl), CbGdDaGdD (dbl), CbGdDaGuD (dbl), CbGdDdGaD (dbl), CbGdDdGdD (dbl),
#   CbGdDdGuD (dbl), CbGdDlAlD (dbl), CbGdDpCpD (dbl), CbGdDpCtD (dbl), CbGdDpSpD
#   (dbl), CbGdDrD (dbl), CbGdDrDrD (dbl), CbGdDtCpD (dbl), CbGdDtCtD (dbl),
#   CbGdDuGaD (dbl), CbGdDuGdD (dbl), CbGdDuGuD (dbl), CbGeAdGaD (dbl), CbGeAdGdD
#   (dbl), CbGeAdGuD (dbl), CbGeAeGdD (dbl), CbGeAeGuD (dbl), CbGeAlD (dbl),
#   CbGeAlDrD (dbl), CbGeAuGaD (dbl), CbGeAuGdD (dbl), CbGeAuGuD (dbl),
#   CbGiG<rGaD (dbl), CbGiG<rGdD (dbl), CbGiG<rGuD (dbl), CbGiGaD (dbl),
#   CbGiGaDrD (dbl), CbGiGbCpD (dbl), CbGiGbCtD (dbl), CbGiGcGaD (dbl), CbGiGcGdD
#   (dbl), CbGiGcGuD (dbl), CbGiGdAlD (dbl), CbGiGdCpD (dbl), CbGiGdCtD (dbl),
#   CbGiGdD (dbl), CbGiGdDrD (dbl), CbGiGeAlD (dbl), CbGiGiGaD (dbl), CbGiGiGdD
#   (dbl), CbGiGiGuD (dbl), CbGiGr>GaD (dbl), CbGiGr>GdD (dbl), CbGiGr>GuD (dbl),
#   CbGiGuAlD (dbl), CbGiGuCpD (dbl), CbGiGuCtD (dbl), CbGiGuD (dbl), CbGiGuDrD
#   (dbl), CbGpBPpGaD (dbl), CbGpBPpGdD (dbl), CbGpBPpGuD (dbl), CbGpCCpGaD
#   (dbl), CbGpCCpGdD (dbl), CbGpCCpGuD (dbl), CbGpMFpGaD (dbl), CbGpMFpGdD
#   (dbl), CbGpMFpGuD (dbl), CbGpPWpGaD (dbl), CbGpPWpGdD (dbl), CbGpPWpGuD
#   (dbl), CbGr>G<rGaD (dbl), CbGr>G<rGdD (dbl), CbGr>G<rGuD (dbl), CbGr>GaD
#   (dbl), CbGr>GaDrD (dbl), CbGr>GbCpD (dbl), CbGr>GbCtD (dbl), CbGr>GcGaD
#   (dbl), CbGr>GcGdD (dbl), CbGr>GcGuD (dbl), CbGr>GdAlD (dbl), CbGr>GdCpD
#   (dbl), CbGr>GdCtD (dbl), CbGr>GdD (dbl), CbGr>GdDrD (dbl), CbGr>GeAlD (dbl),
#   CbGr>GiGaD (dbl), CbGr>GiGdD (dbl), CbGr>GiGuD (dbl), CbGr>Gr>GaD (dbl),
#   CbGr>Gr>GdD (dbl), CbGr>Gr>GuD (dbl), CbGr>GuAlD (dbl), CbGr>GuCpD (dbl),
#   CbGr>GuCtD (dbl), CbGr>GuD (dbl), CbGr>GuDrD (dbl), CbGuAdGaD (dbl),
#   CbGuAdGdD (dbl), CbGuAdGuD (dbl), CbGuAeGaD (dbl), CbGuAeGdD (dbl), CbGuAeGuD
#   (dbl), CbGuAlD (dbl), CbGuAlDrD (dbl), CbGuAuGaD (dbl), CbGuAuGdD (dbl),
#   CbGuAuGuD (dbl), CbGuCbGaD (dbl), CbGuCbGdD (dbl), CbGuCbGuD (dbl), CbGuCdGaD
#   (dbl), CbGuCdGdD (dbl), CbGuCdGuD (dbl), CbGuCpD (dbl), CbGuCpDrD (dbl),
#   CbGuCrCpD (dbl), CbGuCrCtD (dbl), CbGuCtD (dbl), CbGuCtDrD (dbl), CbGuCuGaD
#   (dbl), CbGuCuGdD (dbl), CbGuCuGuD (dbl), CbGuD (dbl), CbGuDaGaD (dbl),
#   CbGuDaGdD (dbl), CbGuDaGuD (dbl), CbGuDdGaD (dbl), CbGuDdGdD (dbl), CbGuDdGuD
#   (dbl), CbGuDlAlD (dbl), CbGuDpCpD (dbl), CbGuDpCtD (dbl), CbGuDpSpD (dbl),
#   CbGuDrD (dbl), CbGuDrDrD (dbl), CbGuDtCpD (dbl), CbGuDtCtD (dbl), CbGuDuGaD
#   (dbl), CbGuDuGdD (dbl), CbGuDuGuD (dbl), CcSEcCbGaD (dbl), CcSEcCbGdD (dbl),
#   CcSEcCbGuD (dbl), CcSEcCdGaD (dbl), CcSEcCdGdD (dbl), CcSEcCdGuD (dbl),
#   CcSEcCpD (dbl), CcSEcCpDrD (dbl), CcSEcCrCpD (dbl), CcSEcCrCtD (dbl),
#   CcSEcCtD (dbl), CcSEcCtDrD (dbl), CcSEcCuGaD (dbl), CcSEcCuGdD (dbl),
#   CcSEcCuGuD (dbl), CdG<rG<rGaD (dbl), CdG<rG<rGdD (dbl), CdG<rG<rGuD (dbl),
#   CdG<rGaD (dbl), CdG<rGaDrD (dbl), CdG<rGbCpD (dbl), CdG<rGbCtD (dbl),
#   CdG<rGcGaD (dbl), CdG<rGcGdD (dbl), CdG<rGcGuD (dbl), CdG<rGdAlD (dbl),
#   CdG<rGdCpD (dbl), CdG<rGdCtD (dbl), CdG<rGdD (dbl), CdG<rGdDrD (dbl),
#   CdG<rGiGaD (dbl), CdG<rGiGdD (dbl), CdG<rGiGuD (dbl), CdG<rGr>GaD (dbl),
#   CdG<rGr>GdD (dbl), CdG<rGr>GuD (dbl), CdG<rGuAlD (dbl), CdG<rGuCpD (dbl),
#   CdG<rGuCtD (dbl), CdG<rGuD (dbl), CdG<rGuDrD (dbl), CdGaD (dbl), CdGaDaGaD
#   (dbl), CdGaDaGdD (dbl), CdGaDaGuD (dbl), CdGaDdGaD (dbl), CdGaDdGdD (dbl),
#   CdGaDdGuD (dbl), CdGaDlAlD (dbl), CdGaDpCpD (dbl), CdGaDpCtD (dbl), CdGaDpSpD
#   (dbl), CdGaDrD (dbl), CdGaDrDrD (dbl), CdGaDtCpD (dbl), CdGaDtCtD (dbl),
#   CdGaDuGaD (dbl), CdGaDuGdD (dbl), CdGaDuGuD (dbl), CdGbCbGaD (dbl), CdGbCbGdD
#   (dbl), CdGbCbGuD (dbl), CdGbCdGaD (dbl), CdGbCdGdD (dbl), CdGbCdGuD (dbl),
#   CdGbCpD (dbl), CdGbCpDrD (dbl), CdGbCrCpD (dbl), CdGbCrCtD (dbl), CdGbCtD
#   (dbl), CdGbCtDrD (dbl), CdGbCuGaD (dbl), CdGbCuGdD (dbl), CdGbCuGuD (dbl),
#   CdGcG<rGaD (dbl), CdGcG<rGdD (dbl), CdGcG<rGuD (dbl), CdGcGaD (dbl),
#   CdGcGaDrD (dbl), CdGcGbCpD (dbl), CdGcGbCtD (dbl), CdGcGcGaD (dbl), CdGcGcGdD
#   (dbl), CdGcGcGuD (dbl), CdGcGdAlD (dbl), CdGcGdCpD (dbl), CdGcGdCtD (dbl),
#   CdGcGdD (dbl), CdGcGdDrD (dbl), CdGcGeAlD (dbl), CdGcGiGaD (dbl), CdGcGiGdD
#   (dbl), CdGcGiGuD (dbl), CdGcGr>GaD (dbl), CdGcGr>GdD (dbl), CdGcGr>GuD (dbl),
#   CdGcGuAlD (dbl), CdGcGuCpD (dbl), CdGcGuCtD (dbl), CdGcGuD (dbl), CdGcGuDrD
#   (dbl), CdGdAdGaD (dbl), CdGdAdGdD (dbl), CdGdAdGuD (dbl), CdGdAeGaD (dbl),
#   CdGdAeGdD (dbl), CdGdAeGuD (dbl), CdGdAlD (dbl), CdGdAlDrD (dbl), CdGdAuGaD
#   (dbl), CdGdAuGdD (dbl), CdGdAuGuD (dbl), CdGdCbGaD (dbl), CdGdCbGdD (dbl),
#   CdGdCbGuD (dbl), CdGdCdGaD (dbl), CdGdCdGdD (dbl), CdGdCdGuD (dbl), CdGdCpD
#   (dbl), CdGdCpDrD (dbl), CdGdCrCpD (dbl), CdGdCrCtD (dbl), CdGdCtD (dbl),
#   CdGdCtDrD (dbl), CdGdCuGaD (dbl), CdGdCuGdD (dbl), CdGdCuGuD (dbl), CdGdD
#   (dbl), CdGdDaGaD (dbl), CdGdDaGdD (dbl), CdGdDaGuD (dbl), CdGdDdGaD (dbl),
#   CdGdDdGdD (dbl), CdGdDdGuD (dbl), CdGdDlAlD (dbl), CdGdDpCpD (dbl), CdGdDpCtD
#   (dbl), CdGdDpSpD (dbl), CdGdDrD (dbl), CdGdDrDrD (dbl), CdGdDtCpD (dbl),
#   CdGdDtCtD (dbl), CdGdDuGaD (dbl), CdGdDuGdD (dbl), CdGdDuGuD (dbl), CdGeAdGaD
#   (dbl), CdGeAdGdD (dbl), CdGeAdGuD (dbl), CdGeAlD (dbl), CdGeAlDrD (dbl),
#   CdGeAuGaD (dbl), CdGeAuGdD (dbl), CdGeAuGuD (dbl), CdGiG<rGaD (dbl),
#   CdGiG<rGdD (dbl), CdGiG<rGuD (dbl), CdGiGaD (dbl), CdGiGaDrD (dbl), CdGiGbCpD
#   (dbl), CdGiGbCtD (dbl), CdGiGcGaD (dbl), CdGiGcGdD (dbl), CdGiGcGuD (dbl),
#   CdGiGdAlD (dbl), CdGiGdCpD (dbl), CdGiGdCtD (dbl), CdGiGdD (dbl), CdGiGdDrD
#   (dbl), CdGiGeAlD (dbl), CdGiGiGaD (dbl), CdGiGiGdD (dbl), CdGiGiGuD (dbl),
#   CdGiGr>GaD (dbl), CdGiGr>GdD (dbl), CdGiGr>GuD (dbl), CdGiGuAlD (dbl),
#   CdGiGuCpD (dbl), CdGiGuCtD (dbl), CdGiGuD (dbl), CdGiGuDrD (dbl), CdGpBPpGaD
#   (dbl), CdGpBPpGdD (dbl), CdGpBPpGuD (dbl), CdGpCCpGaD (dbl), CdGpCCpGdD
#   (dbl), CdGpCCpGuD (dbl), CdGpMFpGaD (dbl), CdGpMFpGdD (dbl), CdGpMFpGuD
#   (dbl), CdGpPWpGaD (dbl), CdGpPWpGdD (dbl), CdGpPWpGuD (dbl), CdGr>G<rGaD
#   (dbl), CdGr>G<rGdD (dbl), CdGr>G<rGuD (dbl), CdGr>GaD (dbl), CdGr>GaDrD
#   (dbl), CdGr>GbCpD (dbl), CdGr>GbCtD (dbl), CdGr>GcGaD (dbl), CdGr>GcGdD
#   (dbl), CdGr>GcGuD (dbl), CdGr>GdAlD (dbl), CdGr>GdCpD (dbl), CdGr>GdCtD
#   (dbl), CdGr>GdD (dbl), CdGr>GdDrD (dbl), CdGr>GeAlD (dbl), CdGr>GiGaD (dbl),
#   CdGr>GiGdD (dbl), CdGr>GiGuD (dbl), CdGr>Gr>GaD (dbl), CdGr>Gr>GdD (dbl),
#   CdGr>Gr>GuD (dbl), CdGr>GuAlD (dbl), CdGr>GuCpD (dbl), CdGr>GuCtD (dbl),
#   CdGr>GuD (dbl), CdGr>GuDrD (dbl), CdGuAdGaD (dbl), CdGuAdGdD (dbl), CdGuAdGuD
#   (dbl), CdGuAeGaD (dbl), CdGuAeGdD (dbl), CdGuAeGuD (dbl), CdGuAlD (dbl),
#   CdGuAlDrD (dbl), CdGuAuGaD (dbl), CdGuAuGdD (dbl), CdGuAuGuD (dbl), CdGuCbGaD
#   (dbl), CdGuCbGdD (dbl), CdGuCbGuD (dbl), CdGuCdGaD (dbl), CdGuCdGdD (dbl),
#   CdGuCdGuD (dbl), CdGuCpD (dbl), CdGuCpDrD (dbl), CdGuCrCpD (dbl), CdGuCrCtD
#   (dbl), CdGuCtD (dbl), CdGuCtDrD (dbl), CdGuCuGaD (dbl), CdGuCuGdD (dbl),
#   CdGuCuGuD (dbl), CdGuD (dbl), CdGuDaGaD (dbl), CdGuDaGdD (dbl), CdGuDaGuD
#   (dbl), CdGuDdGaD (dbl), CdGuDdGdD (dbl), CdGuDdGuD (dbl), CdGuDlAlD (dbl),
#   CdGuDpCpD (dbl), CdGuDpCtD (dbl), CdGuDpSpD (dbl), CdGuDrD (dbl), CdGuDrDrD
#   (dbl), CdGuDtCpD (dbl), CdGuDtCtD (dbl), CdGuDuGaD (dbl), CdGuDuGdD (dbl),
#   CdGuDuGuD (dbl), CiPCiCbGaD (dbl), CiPCiCbGdD (dbl), CiPCiCbGuD (dbl),
#   CiPCiCdGaD (dbl), CiPCiCdGdD (dbl), CiPCiCdGuD (dbl), CiPCiCpD (dbl),
#   CiPCiCpDrD (dbl), CiPCiCrCpD (dbl), CiPCiCrCtD (dbl), CiPCiCtD (dbl),
#   CiPCiCtDrD (dbl), CiPCiCuGaD (dbl), CiPCiCuGdD (dbl), CiPCiCuGuD (dbl),
#   CpDaG<rGaD (dbl), CpDaG<rGdD (dbl), CpDaG<rGuD (dbl), CpDaGaD (dbl),
#   CpDaGaDrD (dbl), CpDaGbCpD (dbl), CpDaGbCtD (dbl), CpDaGcGaD (dbl), CpDaGcGdD
#   (dbl), CpDaGcGuD (dbl), CpDaGdAlD (dbl), CpDaGdCpD (dbl), CpDaGdCtD (dbl),
#   CpDaGdD (dbl), CpDaGdDrD (dbl), CpDaGeAlD (dbl), CpDaGiGaD (dbl), CpDaGiGdD
#   (dbl), CpDaGiGuD (dbl), CpDaGr>GaD (dbl), CpDaGr>GdD (dbl), CpDaGr>GuD (dbl),
#   CpDaGuAlD (dbl), CpDaGuCpD (dbl), CpDaGuCtD (dbl), CpDaGuD (dbl), CpDaGuDrD
#   (dbl), CpDdG<rGaD (dbl), CpDdG<rGdD (dbl), CpDdG<rGuD (dbl), CpDdGaD (dbl),
#   CpDdGaDrD (dbl), CpDdGbCpD (dbl), CpDdGbCtD (dbl), CpDdGcGaD (dbl), CpDdGcGdD
#   (dbl), CpDdGcGuD (dbl), CpDdGdAlD (dbl), CpDdGdCpD (dbl), CpDdGdCtD (dbl),
#   CpDdGdD (dbl), CpDdGdDrD (dbl), CpDdGeAlD (dbl), CpDdGiGaD (dbl), CpDdGiGdD
#   (dbl), CpDdGiGuD (dbl), CpDdGr>GaD (dbl), CpDdGr>GdD (dbl), CpDdGr>GuD (dbl),
#   CpDdGuAlD (dbl), CpDdGuCpD (dbl), CpDdGuCtD (dbl), CpDdGuD (dbl), CpDdGuDrD
#   (dbl), CpDlAdGaD (dbl), CpDlAdGdD (dbl), CpDlAdGuD (dbl), CpDlAeGaD (dbl),
#   CpDlAeGdD (dbl), CpDlAeGuD (dbl), CpDlAlD (dbl), CpDlAlDrD (dbl), CpDlAuGaD
#   (dbl), CpDlAuGdD (dbl), CpDlAuGuD (dbl), CpDpCbGaD (dbl), CpDpCbGdD (dbl),
#   CpDpCbGuD (dbl), CpDpCdGaD (dbl), CpDpCdGdD (dbl), CpDpCdGuD (dbl), CpDpCpD
#   (dbl), CpDpCpDrD (dbl), CpDpCrCpD (dbl), CpDpCrCtD (dbl), CpDpCtD (dbl),
#   CpDpCtDrD (dbl), CpDpCuGaD (dbl), CpDpCuGdD (dbl), CpDpCuGuD (dbl), CpDpSpD
#   (dbl), CpDpSpDrD (dbl), CpDrD (dbl), CpDrDaGaD (dbl), CpDrDaGdD (dbl),
#   CpDrDaGuD (dbl), CpDrDdGaD (dbl), CpDrDdGdD (dbl), CpDrDdGuD (dbl), CpDrDlAlD
#   (dbl), CpDrDpCpD (dbl), CpDrDpCtD (dbl), CpDrDpSpD (dbl), CpDrDrD (dbl),
#   CpDrDrDrD (dbl), CpDrDtCpD (dbl), CpDrDtCtD (dbl), CpDrDuGaD (dbl), CpDrDuGdD
#   (dbl), CpDrDuGuD (dbl), CpDtCbGaD (dbl), CpDtCbGdD (dbl), CpDtCbGuD (dbl),
#   CpDtCdGaD (dbl), CpDtCdGdD (dbl), CpDtCdGuD (dbl), CpDtCpD (dbl), CpDtCpDrD
#   (dbl), CpDtCrCpD (dbl), CpDtCrCtD (dbl), CpDtCtD (dbl), CpDtCtDrD (dbl),
#   CpDtCuGaD (dbl), CpDtCuGdD (dbl), CpDtCuGuD (dbl), CpDuG<rGaD (dbl),
#   CpDuG<rGdD (dbl), CpDuG<rGuD (dbl), CpDuGaD (dbl), CpDuGaDrD (dbl), CpDuGbCpD
#   (dbl), CpDuGbCtD (dbl), CpDuGcGaD (dbl), CpDuGcGdD (dbl), CpDuGcGuD (dbl),
#   CpDuGdAlD (dbl), CpDuGdCpD (dbl), CpDuGdCtD (dbl), CpDuGdD (dbl), CpDuGdDrD
#   (dbl), CpDuGeAlD (dbl), CpDuGiGaD (dbl), CpDuGiGdD (dbl), CpDuGiGuD (dbl),
#   CpDuGr>GaD (dbl), CpDuGr>GdD (dbl), CpDuGr>GuD (dbl), CpDuGuAlD (dbl),
#   CpDuGuCpD (dbl), CpDuGuCtD (dbl), CpDuGuD (dbl), CpDuGuDrD (dbl), CrCbG<rGaD
#   (dbl), CrCbG<rGdD (dbl), CrCbG<rGuD (dbl), CrCbGaD (dbl), CrCbGaDrD (dbl),
#   CrCbGbCpD (dbl), CrCbGbCtD (dbl), CrCbGcGaD (dbl), CrCbGcGdD (dbl), CrCbGcGuD
#   (dbl), CrCbGdAlD (dbl), CrCbGdCpD (dbl), CrCbGdCtD (dbl), CrCbGdD (dbl),
#   CrCbGdDrD (dbl), CrCbGeAlD (dbl), CrCbGiGaD (dbl), CrCbGiGdD (dbl), CrCbGiGuD
#   (dbl), CrCbGr>GaD (dbl), CrCbGr>GdD (dbl), CrCbGr>GuD (dbl), CrCbGuAlD (dbl),
#   CrCbGuCpD (dbl), CrCbGuCtD (dbl), CrCbGuD (dbl), CrCbGuDrD (dbl), CrCcSEcCpD
#   (dbl), CrCcSEcCtD (dbl), CrCdG<rGaD (dbl), CrCdG<rGdD (dbl), CrCdG<rGuD
#   (dbl), CrCdGaD (dbl), CrCdGaDrD (dbl), CrCdGbCpD (dbl), CrCdGbCtD (dbl),
#   CrCdGcGaD (dbl), CrCdGcGdD (dbl), CrCdGcGuD (dbl), CrCdGdAlD (dbl), CrCdGdCpD
#   (dbl), CrCdGdCtD (dbl), CrCdGdD (dbl), CrCdGdDrD (dbl), CrCdGeAlD (dbl),
#   CrCdGiGaD (dbl), CrCdGiGdD (dbl), CrCdGiGuD (dbl), CrCdGr>GaD (dbl),
#   CrCdGr>GdD (dbl), CrCdGr>GuD (dbl), CrCdGuAlD (dbl), CrCdGuCpD (dbl),
#   CrCdGuCtD (dbl), CrCdGuD (dbl), CrCdGuDrD (dbl), CrCiPCiCpD (dbl), CrCiPCiCtD
#   (dbl), CrCpD (dbl), CrCpDaGaD (dbl), CrCpDaGdD (dbl), CrCpDaGuD (dbl),
#   CrCpDdGaD (dbl), CrCpDdGdD (dbl), CrCpDdGuD (dbl), CrCpDlAlD (dbl), CrCpDpCpD
#   (dbl), CrCpDpCtD (dbl), CrCpDpSpD (dbl), CrCpDrD (dbl), CrCpDrDrD (dbl),
#   CrCpDtCpD (dbl), CrCpDtCtD (dbl), CrCpDuGaD (dbl), CrCpDuGdD (dbl), CrCpDuGuD
#   (dbl), CrCrCbGaD (dbl), CrCrCbGdD (dbl), CrCrCbGuD (dbl), CrCrCdGaD (dbl),
#   CrCrCdGdD (dbl), CrCrCdGuD (dbl), CrCrCpD (dbl), CrCrCpDrD (dbl), CrCrCrCpD
#   (dbl), CrCrCrCtD (dbl), CrCrCtD (dbl), CrCrCtDrD (dbl), CrCrCuGaD (dbl),
#   CrCrCuGdD (dbl), CrCrCuGuD (dbl), CrCtD (dbl), CrCtDaGaD (dbl), CrCtDaGdD
#   (dbl), CrCtDaGuD (dbl), CrCtDdGaD (dbl), CrCtDdGdD (dbl), CrCtDdGuD (dbl),
#   CrCtDlAlD (dbl), CrCtDpCpD (dbl), CrCtDpCtD (dbl), CrCtDpSpD (dbl), CrCtDrD
#   (dbl), CrCtDrDrD (dbl), CrCtDtCpD (dbl), CrCtDtCtD (dbl), CrCtDuGaD (dbl),
#   CrCtDuGdD (dbl), CrCtDuGuD (dbl), CrCuG<rGaD (dbl), CrCuG<rGdD (dbl),
#   CrCuG<rGuD (dbl), CrCuGaD (dbl), CrCuGaDrD (dbl), CrCuGbCpD (dbl), CrCuGbCtD
#   (dbl), CrCuGcGaD (dbl), CrCuGcGdD (dbl), CrCuGcGuD (dbl), CrCuGdAlD (dbl),
#   CrCuGdCpD (dbl), CrCuGdCtD (dbl), CrCuGdD (dbl), CrCuGdDrD (dbl), CrCuGeAlD
#   (dbl), CrCuGiGaD (dbl), CrCuGiGdD (dbl), CrCuGiGuD (dbl), CrCuGr>GaD (dbl),
#   CrCuGr>GdD (dbl), CrCuGr>GuD (dbl), CrCuGuAlD (dbl), CrCuGuCpD (dbl),
#   CrCuGuCtD (dbl), CrCuGuD (dbl), CrCuGuDrD (dbl), CtDaG<rGaD (dbl), CtDaG<rGdD
#   (dbl), CtDaG<rGuD (dbl), CtDaGaD (dbl), CtDaGaDrD (dbl), CtDaGbCpD (dbl),
#   CtDaGbCtD (dbl), CtDaGcGaD (dbl), CtDaGcGdD (dbl), CtDaGcGuD (dbl), CtDaGdAlD
#   (dbl), CtDaGdCpD (dbl), CtDaGdCtD (dbl), CtDaGdD (dbl), CtDaGdDrD (dbl),
#   CtDaGeAlD (dbl), CtDaGiGaD (dbl), CtDaGiGdD (dbl), CtDaGiGuD (dbl),
#   CtDaGr>GaD (dbl), CtDaGr>GdD (dbl), CtDaGr>GuD (dbl), CtDaGuAlD (dbl),
#   CtDaGuCpD (dbl), CtDaGuCtD (dbl), CtDaGuD (dbl), CtDaGuDrD (dbl), CtDdG<rGaD
#   (dbl), CtDdG<rGdD (dbl), CtDdG<rGuD (dbl), CtDdGaD (dbl), CtDdGaDrD (dbl),
#   CtDdGbCpD (dbl), CtDdGbCtD (dbl), CtDdGcGaD (dbl), CtDdGcGdD (dbl), CtDdGcGuD
#   (dbl), CtDdGdAlD (dbl), CtDdGdCpD (dbl), CtDdGdCtD (dbl), CtDdGdD (dbl),
#   CtDdGdDrD (dbl), CtDdGeAlD (dbl), CtDdGiGaD (dbl), CtDdGiGdD (dbl), CtDdGiGuD
#   (dbl), CtDdGr>GaD (dbl), CtDdGr>GdD (dbl), CtDdGr>GuD (dbl), CtDdGuAlD (dbl),
#   CtDdGuCpD (dbl), CtDdGuCtD (dbl), CtDdGuD (dbl), CtDdGuDrD (dbl), CtDlAdGaD
#   (dbl), CtDlAdGdD (dbl), CtDlAdGuD (dbl), CtDlAeGaD (dbl), CtDlAeGdD (dbl),
#   CtDlAeGuD (dbl), CtDlAlD (dbl), CtDlAlDrD (dbl), CtDlAuGaD (dbl), CtDlAuGdD
#   (dbl), CtDlAuGuD (dbl), CtDpCbGaD (dbl), CtDpCbGdD (dbl), CtDpCbGuD (dbl),
#   CtDpCdGaD (dbl), CtDpCdGdD (dbl), CtDpCdGuD (dbl), CtDpCpD (dbl), CtDpCpDrD
#   (dbl), CtDpCrCpD (dbl), CtDpCrCtD (dbl), CtDpCtD (dbl), CtDpCtDrD (dbl),
#   CtDpCuGaD (dbl), CtDpCuGdD (dbl), CtDpCuGuD (dbl), CtDpSpD (dbl), CtDpSpDrD
#   (dbl), CtDrD (dbl), CtDrDaGaD (dbl), CtDrDaGdD (dbl), CtDrDaGuD (dbl),
#   CtDrDdGaD (dbl), CtDrDdGdD (dbl), CtDrDdGuD (dbl), CtDrDlAlD (dbl), CtDrDpCpD
#   (dbl), CtDrDpCtD (dbl), CtDrDpSpD (dbl), CtDrDrD (dbl), CtDrDrDrD (dbl),
#   CtDrDtCpD (dbl), CtDrDtCtD (dbl), CtDrDuGaD (dbl), CtDrDuGdD (dbl), CtDrDuGuD
#   (dbl), CtDtCbGaD (dbl), CtDtCbGdD (dbl), CtDtCbGuD (dbl), CtDtCdGaD (dbl),
#   CtDtCdGdD (dbl), CtDtCdGuD (dbl), CtDtCpD (dbl), CtDtCpDrD (dbl), CtDtCrCpD
#   (dbl), CtDtCrCtD (dbl), CtDtCtD (dbl), CtDtCtDrD (dbl), CtDtCuGaD (dbl),
#   CtDtCuGdD (dbl), CtDtCuGuD (dbl), CtDuG<rGaD (dbl), CtDuG<rGdD (dbl),
#   CtDuG<rGuD (dbl), CtDuGaD (dbl), CtDuGaDrD (dbl), CtDuGbCpD (dbl), CtDuGbCtD
#   (dbl), CtDuGcGaD (dbl), CtDuGcGdD (dbl), CtDuGcGuD (dbl), CtDuGdAlD (dbl),
#   CtDuGdCpD (dbl), CtDuGdCtD (dbl), CtDuGdD (dbl), CtDuGdDrD (dbl), CtDuGeAlD
#   (dbl), CtDuGiGaD (dbl), CtDuGiGdD (dbl), CtDuGiGuD (dbl), CtDuGr>GaD (dbl),
#   CtDuGr>GdD (dbl), CtDuGr>GuD (dbl), CtDuGuAlD (dbl), CtDuGuCpD (dbl),
#   CtDuGuCtD (dbl), CtDuGuD (dbl), CtDuGuDrD (dbl), CuG<rG<rGaD (dbl),
#   CuG<rG<rGdD (dbl), CuG<rG<rGuD (dbl), CuG<rGaD (dbl), CuG<rGaDrD (dbl),
#   CuG<rGbCpD (dbl), CuG<rGbCtD (dbl), CuG<rGcGaD (dbl), CuG<rGcGdD (dbl),
#   CuG<rGcGuD (dbl), CuG<rGdAlD (dbl), CuG<rGdCpD (dbl), CuG<rGdCtD (dbl),
#   CuG<rGdD (dbl), CuG<rGdDrD (dbl), CuG<rGiGaD (dbl), CuG<rGiGdD (dbl),
#   CuG<rGiGuD (dbl), CuG<rGr>GaD (dbl), CuG<rGr>GdD (dbl), CuG<rGr>GuD (dbl),
#   CuG<rGuAlD (dbl), CuG<rGuCpD (dbl), CuG<rGuCtD (dbl), CuG<rGuD (dbl),
#   CuG<rGuDrD (dbl), CuGaD (dbl), CuGaDaGaD (dbl), CuGaDaGdD (dbl), CuGaDaGuD
#   (dbl), CuGaDdGaD (dbl), CuGaDdGdD (dbl), CuGaDdGuD (dbl), CuGaDlAlD (dbl),
#   CuGaDpCpD (dbl), CuGaDpCtD (dbl), CuGaDpSpD (dbl), CuGaDrD (dbl), CuGaDrDrD
#   (dbl), CuGaDtCpD (dbl), CuGaDtCtD (dbl), CuGaDuGaD (dbl), CuGaDuGdD (dbl),
#   CuGaDuGuD (dbl), CuGbCbGaD (dbl), CuGbCbGdD (dbl), CuGbCbGuD (dbl), CuGbCdGaD
#   (dbl), CuGbCdGdD (dbl), CuGbCdGuD (dbl), CuGbCpD (dbl), CuGbCpDrD (dbl),
#   CuGbCrCpD (dbl), CuGbCrCtD (dbl), CuGbCtD (dbl), CuGbCtDrD (dbl), CuGbCuGaD
#   (dbl), CuGbCuGdD (dbl), CuGbCuGuD (dbl), CuGcG<rGaD (dbl), CuGcG<rGdD (dbl),
#   CuGcG<rGuD (dbl), CuGcGaD (dbl), CuGcGaDrD (dbl), CuGcGbCpD (dbl), CuGcGbCtD
#   (dbl), CuGcGcGaD (dbl), CuGcGcGdD (dbl), CuGcGcGuD (dbl), CuGcGdAlD (dbl),
#   CuGcGdCpD (dbl), CuGcGdCtD (dbl), CuGcGdD (dbl), CuGcGdDrD (dbl), CuGcGeAlD
#   (dbl), CuGcGiGaD (dbl), CuGcGiGdD (dbl), CuGcGiGuD (dbl), CuGcGr>GaD (dbl),
#   CuGcGr>GdD (dbl), CuGcGr>GuD (dbl), CuGcGuAlD (dbl), CuGcGuCpD (dbl),
#   CuGcGuCtD (dbl), CuGcGuD (dbl), CuGcGuDrD (dbl), CuGdAdGaD (dbl), CuGdAdGdD
#   (dbl), CuGdAdGuD (dbl), CuGdAeGaD (dbl), CuGdAeGdD (dbl), CuGdAeGuD (dbl),
#   CuGdAlD (dbl), CuGdAlDrD (dbl), CuGdAuGaD (dbl), CuGdAuGdD (dbl), CuGdAuGuD
#   (dbl), CuGdCbGaD (dbl), CuGdCbGdD (dbl), CuGdCbGuD (dbl), CuGdCdGaD (dbl),
#   CuGdCdGdD (dbl), CuGdCdGuD (dbl), CuGdCpD (dbl), CuGdCpDrD (dbl), CuGdCrCpD
#   (dbl), CuGdCrCtD (dbl), CuGdCtD (dbl), CuGdCtDrD (dbl), CuGdCuGaD (dbl),
#   CuGdCuGdD (dbl), CuGdCuGuD (dbl), CuGdD (dbl), CuGdDaGaD (dbl), CuGdDaGdD
#   (dbl), CuGdDaGuD (dbl), CuGdDdGaD (dbl), CuGdDdGdD (dbl), CuGdDdGuD (dbl),
#   CuGdDlAlD (dbl), CuGdDpCpD (dbl), CuGdDpCtD (dbl), CuGdDpSpD (dbl), CuGdDrD
#   (dbl), CuGdDrDrD (dbl), CuGdDtCpD (dbl), CuGdDtCtD (dbl), CuGdDuGaD (dbl),
#   CuGdDuGdD (dbl), CuGdDuGuD (dbl), CuGeAdGaD (dbl), CuGeAdGdD (dbl), CuGeAdGuD
#   (dbl), CuGeAlD (dbl), CuGeAlDrD (dbl), CuGeAuGdD (dbl), CuGeAuGuD (dbl),
#   CuGiG<rGaD (dbl), CuGiG<rGdD (dbl), CuGiG<rGuD (dbl), CuGiGaD (dbl),
#   CuGiGaDrD (dbl), CuGiGbCpD (dbl), CuGiGbCtD (dbl), CuGiGcGaD (dbl), CuGiGcGdD
#   (dbl), CuGiGcGuD (dbl), CuGiGdAlD (dbl), CuGiGdCpD (dbl), CuGiGdCtD (dbl),
#   CuGiGdD (dbl), CuGiGdDrD (dbl), CuGiGeAlD (dbl), CuGiGiGaD (dbl), CuGiGiGdD
#   (dbl), CuGiGiGuD (dbl), CuGiGr>GaD (dbl), CuGiGr>GdD (dbl), CuGiGr>GuD (dbl),
#   CuGiGuAlD (dbl), CuGiGuCpD (dbl), CuGiGuCtD (dbl), CuGiGuD (dbl), CuGiGuDrD
#   (dbl), CuGpBPpGaD (dbl), CuGpBPpGdD (dbl), CuGpBPpGuD (dbl), CuGpCCpGaD
#   (dbl), CuGpCCpGdD (dbl), CuGpCCpGuD (dbl), CuGpMFpGaD (dbl), CuGpMFpGdD
#   (dbl), CuGpMFpGuD (dbl), CuGpPWpGaD (dbl), CuGpPWpGdD (dbl), CuGpPWpGuD
#   (dbl), CuGr>G<rGaD (dbl), CuGr>G<rGdD (dbl), CuGr>G<rGuD (dbl), CuGr>GaD
#   (dbl), CuGr>GaDrD (dbl), CuGr>GbCpD (dbl), CuGr>GbCtD (dbl), CuGr>GcGaD
#   (dbl), CuGr>GcGdD (dbl), CuGr>GcGuD (dbl), CuGr>GdAlD (dbl), CuGr>GdCpD
#   (dbl), CuGr>GdCtD (dbl), CuGr>GdD (dbl), CuGr>GdDrD (dbl), CuGr>GeAlD (dbl),
#   CuGr>GiGaD (dbl), CuGr>GiGdD (dbl), CuGr>GiGuD (dbl), CuGr>Gr>GaD (dbl),
#   CuGr>Gr>GdD (dbl), CuGr>Gr>GuD (dbl), CuGr>GuAlD (dbl), CuGr>GuCpD (dbl),
#   CuGr>GuCtD (dbl), CuGr>GuD (dbl), CuGr>GuDrD (dbl), CuGuAdGaD (dbl),
#   CuGuAdGdD (dbl), CuGuAdGuD (dbl), CuGuAeGaD (dbl), CuGuAeGdD (dbl), CuGuAeGuD
#   (dbl), CuGuAlD (dbl), CuGuAlDrD (dbl), CuGuAuGaD (dbl), CuGuAuGdD (dbl),
#   CuGuAuGuD (dbl), CuGuCbGaD (dbl), CuGuCbGdD (dbl), CuGuCbGuD (dbl), CuGuCdGaD
#   (dbl), CuGuCdGdD (dbl), CuGuCdGuD (dbl), CuGuCpD (dbl), CuGuCpDrD (dbl),
#   CuGuCrCpD (dbl), CuGuCrCtD (dbl), CuGuCtD (dbl), CuGuCtDrD (dbl), CuGuCuGaD
#   (dbl), CuGuCuGdD (dbl), CuGuCuGuD (dbl), CuGuD (dbl), CuGuDaGaD (dbl),
#   CuGuDaGdD (dbl), CuGuDaGuD (dbl), CuGuDdGaD (dbl), CuGuDdGdD (dbl), CuGuDdGuD
#   (dbl), CuGuDlAlD (dbl), CuGuDpCpD (dbl), CuGuDpCtD (dbl), CuGuDpSpD (dbl),
#   CuGuDrD (dbl), CuGuDrDrD (dbl), CuGuDtCpD (dbl), CuGuDtCtD (dbl), CuGuDuGaD
#   (dbl), CuGuDuGdD (dbl), CuGuDuGuD (dbl)

# %%
fit_list = list()
i = 0
get_performance = function(df, incl_degrees) {
  for (seed in 1:5) {
    for (alpha in 0:1) {
      i <<- i + 1
      y = df$status
      X = df %>% dplyr::select(-status, -hetnet) %>% as.matrix()
      penalty_factor = ifelse(colnames(X) == 'prior_logit', 0, 1)
      fit = hetior::glmnet_train(X = X, y = y, alpha = alpha, cores = 5, seed=seed,
        penalty.factor=penalty_factor, lambda.min.ratio=1e-6, nlambda=200
      )
      fit$name = df$hetnet[1]
      fit$incl_degrees = incl_degrees
      fit_list[[i]] <<- fit
    }
  }
  return(data.frame(i))
}

temp = transformed_df %>%
  dplyr::group_by(hetnet) %>%
  dplyr::do(get_performance(., incl_degrees=1))

temp = transformed_df %>%
  dplyr::select(-one_of(degrees)) %>%
  dplyr::group_by(hetnet) %>%
  dplyr::do(get_performance(., incl_degrees=0))
# Out:
# Loading required package: Matrix
# Loading required package: foreach
# Loaded glmnet 2.0-5

# %%
result_df = fit_list %>% lapply(function(l) {
  dplyr::data_frame(
    name = l$name,
    alpha = l$alpha,
    incl_degrees = l$incl_degrees,
    seed = l$seed,
    auroc = l$vtm$auroc,
    auprc = l$vtm$auprc,
    tjur = l$vtm$tjur
  )
    
}) %>% dplyr::rbind_all()

head(result_df, 2)
# Out:
# Source: local data frame [2 x 7]
#
#            name alpha incl_degrees  seed    auroc     auprc      tjur
#           (chr) (int)        (dbl) (int)    (dbl)     (dbl)     (dbl)
# 1 rephetio-v2.0     0            1     1 0.991685 0.9738731 0.7414739
# 2 rephetio-v2.0     1            1     1 0.993174 0.9745725 0.7897991

# %%
result_df %>% readr::write_tsv('data/model-performances.tsv')

# %%
summary_df = result_df %>%
  dplyr::mutate(permuted = as.integer(grepl('perm', result_df$name))) %>%
  dplyr::group_by(permuted, alpha, incl_degrees, alpha) %>%
  dplyr::do(
    dplyr::bind_cols(
      ggplot2::mean_cl_normal(.$tjur) %>% dplyr::rename(tjur=y, tjur_lower=ymin, tjur_upper=ymax),
      ggplot2::mean_cl_normal(.$auroc) %>% dplyr::rename(auroc=y, auroc_lower=ymin, auroc_upper=ymax),
      ggplot2::mean_cl_normal(.$auprc) %>% dplyr::rename(auprc=y, auprc_lower=ymin, auprc_upper=ymax))
  ) %>%
  dplyr::ungroup() %>%
  dplyr::arrange(desc(tjur))

summary_df %>% readr::write_tsv('data/model-performances-summary.tsv')
summary_df
# Out:
# Source: local data frame [8 x 12]
#
#   permuted alpha incl_degrees      tjur tjur_lower tjur_upper     auroc
#      (int) (int)        (dbl)     (dbl)      (dbl)      (dbl)     (dbl)
# 1        0     1            1 0.7842567  0.7770510  0.7914623 0.9925687
# 2        0     0            1 0.7457139  0.7371756  0.7542523 0.9921086
# 3        0     1            0 0.7259513  0.7259513  0.7259513 0.9811947
# 4        0     0            0 0.7127112  0.7041414  0.7212811 0.9871499
# 5        1     1            1 0.6960590  0.6861327  0.7059853 0.9834288
# 6        1     0            1 0.6700250  0.6594773  0.6805727 0.9850796
# 7        1     1            0 0.6337473  0.6255932  0.6419013 0.9717641
# 8        1     0            0 0.6066769  0.5966338  0.6167200 0.9742294
# Variables not shown: auroc_lower (dbl), auroc_upper (dbl), auprc (dbl),
#   auprc_lower (dbl), auprc_upper (dbl)
