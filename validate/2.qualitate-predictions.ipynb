# %% [markdown]
# # Exploratory / Incomplete: predictions on historical repurposing examples

# %%
import pandas

# %%
example_df = pandas.read_table('./repurposing-examples.tsv')

# %%
prob_df = pandas.read_table('../prediction/predictions/probabilities.tsv')
example_df = example_df.merge(prob_df)
example_df[['compound_name', 'disease_name', 'history', 'category', 'prediction', 'compound_percentile', 'disease_percentile']]
# Out:
#    compound_name                              disease_name   history category  \
# 0      Bupropion                     endogenous depression  original      NaN
# 1      Bupropion                       nicotine dependence       new      NaN
# 2    Sibutramine                     endogenous depression  original      NaN
# 3    Sibutramine                                   obesity       new       DM
# 4      Minoxidil                              hypertension  original       DM
# 5      Minoxidil                           alopecia areata       new      NaN
# 6   Methotrexate                             breast cancer  original       DM
# 7   Methotrexate                      rheumatoid arthritis       new       DM
# 8    Atomoxetine                       Parkinson's disease  original      NaN
# 9    Atomoxetine  attention deficit hyperactivity disorder       new      SYM
# 10    Topiramate                         epilepsy syndrome  original       DM
# ...

# %%
compound_df = pandas.read_table('../summary/compounds.tsv')
disease_df = pandas.read_table('../summary/diseases.tsv')
